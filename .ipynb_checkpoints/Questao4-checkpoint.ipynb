# %% [markdown]
# # Questao 4 - Dados
# Problemática: alguns produtos podem ter sido vendidos abaixo do custo, possivelmente por erro operacional.
# Causa:
#
#     O sistema de vendas (vendas_2023_2024.csv) registra valores em real BRL
#     O catálogo de fornecedores (custos_importacao.json) registra custos unitários em dollar USD
#     O câmbio varia diariamente
#
# Objetivo:Cruzar o custo em dólar do dia da venda com o valor de venda em reais
# para identificar onde houve prejuízo real.

# %% [markdown]
# ### 1. Importação de Bibliotecas e Requisição

# %%
# importação de bibliotecas
import requests
import pandas as pd
import sqlite3

# %%
# URL da API do Banco Central com dados de 2025 até 2025.
url_bcb = "https://olinda.bcb.gov.br/olinda/servico/PTAX/versao/v1/odata/CotacaoDolarPeriodo(dataInicial=@dataInicial,dataFinalCotacao=@dataFinalCotacao)?@dataInicial='01-04-2016'&@dataFinalCotacao='12-31-2025'&$top=10000&$format=json&$select=cotacaoCompra,cotacaoVenda,dataHoraCotacao"

# %%
# Fazendo a requisição
response = requests.get(url_bcb)
dados_json = response.json()

# %%
#visuallização inicial
dados_json
# Out:
# {'@odata.context': 'https://was-p.bcnet.bcb.gov.br/olinda/servico/PTAX/versao/v1/odata$metadata#_CotacaoDolarPeriodo(cotacaoCompra,cotacaoVenda,dataHoraCotacao)',
#  'value': [{'cotacaoCompra': 4.038,
#    'cotacaoVenda': 4.0387,
#    'dataHoraCotacao': '2016-01-04 13:12:41.021'},
#   {'cotacaoCompra': 4.0108,
#    'cotacaoVenda': 4.0114,
#    'dataHoraCotacao': '2016-01-05 13:12:41.306'},
#   {'cotacaoCompra': 4.0297,
#    'cotacaoVenda': 4.0303,
#    'dataHoraCotacao': '2016-01-06 13:08:04.506'},
#   {'cotacaoCompra': 4.0469,
#    'cotacaoVenda': 4.0475,
#    'dataHoraCotacao': '2016-01-07 13:07:20.817'},
#   {'cotacaoCompra': 4.0244,
#    'cotacaoVenda': 4.025,
#    'dataHoraCotacao': '2016-01-08 13:11:21.614'},
#   {'cotacaoCompra': 4.0147,
#    'cotacaoVenda': 4.0153,
#    'dataHoraCotacao': '2016-01-11 13:08:12.021'},
#   {'cotacaoCompra': 4.0293,
#    'cotacaoVenda': 4.0299,
#    'dataHoraCotacao': '2016-01-12 13:10:57.893'},
#   {'cotacaoCompra': 3.9857,
#    'cotacaoVenda': 3.9863,
#    'dataHoraCotacao': '2016-01-13 13:07:21.557'},
#   {'cotacaoCompra': 4.0217,
#    'cotacaoVenda': 4.0223,
#    'dataHoraCotacao': '2016-01-14 13:03:00.94'},
#   {'cotacaoCompra': 4.0396,
#    'cotacaoVenda': 4.0402,
#    'dataHoraCotacao': '2016-01-15 13:08:54.259'},
#   {'cotacaoCompra': 4.0358,
#    'cotacaoVenda': 4.0364,
#    'dataHoraCotacao': '2016-01-18 13:09:25.047'},
#   {'cotacaoCompra': 4.0297,
#    'cotacaoVenda': 4.0303,
#    'dataHoraCotacao': '2016-01-19 13:08:59.557'},
#   {'cotacaoCompra': 4.0855,
#    'cotacaoVenda': 4.0861,
#    'dataHoraCotacao': '2016-01-20 13:06:47.722'},
#   {'cotacaoCompra': 4.1552,
#    'cotacaoVenda': 4.1558,
#    'dataHoraCotacao': '2016-01-21 13:07:17.33'},
#   {'cotacaoCompra': 4.1226,
#    'cotacaoVenda': 4.1232,
#    'dataHoraCotacao': '2016-01-22 13:11:51.506'},
#   {'cotacaoCompra': 4.0991,
#    'cotacaoVenda': 4.1002,
#    'dataHoraCotacao': '2016-01-25 13:05:43.322'},
#   {'cotacaoCompra': 4.0961,
#    'cotacaoVenda': 4.0967,
#    'dataHoraCotacao': '2016-01-26 13:11:08.831'},
#   {'cotacaoCompra': 4.0441,
#    'cotacaoVenda': 4.0448,
#    'dataHoraCotacao': '2016-01-27 13:07:42.731'},
#   {'cotacaoCompra': 4.0832,
#    'cotacaoVenda': 4.0838,
#    'dataHoraCotacao': '2016-01-28 13:12:28.371'},
#   {'cotacaoCompra': 4.0422,
#    'cotacaoVenda': 4.0428,
#    'dataHoraCotacao': '2016-01-29 13:08:00.674'},
#   {'cotacaoCompra': 3.9979,
#    'cotacaoVenda': 3.9986,
#    'dataHoraCotacao': '2016-02-01 13:03:39.417'},
#   {'cotacaoCompra': 3.9913,
#    'cotacaoVenda': 3.9919,
#    'dataHoraCotacao': '2016-02-02 13:02:59.245'},
#   {'cotacaoCompra': 3.9552,
#    'cotacaoVenda': 3.9558,
#    'dataHoraCotacao': '2016-02-03 13:09:54.357'},
#   {'cotacaoCompra': 3.8646,
#    'cotacaoVenda': 3.8653,
#    'dataHoraCotacao': '2016-02-04 13:06:21.252'},
#   {'cotacaoCompra': 3.8969,
#    'cotacaoVenda': 3.8975,
#    'dataHoraCotacao': '2016-02-05 13:10:29.963'},
#   {'cotacaoCompra': 3.9406,
#    'cotacaoVenda': 3.9412,
#    'dataHoraCotacao': '2016-02-10 15:36:18.369'},
#   {'cotacaoCompra': 3.9636,
#    'cotacaoVenda': 3.9642,
#    'dataHoraCotacao': '2016-02-11 13:07:15.167'},
#   {'cotacaoCompra': 3.9884,
#    'cotacaoVenda': 3.9891,
#    'dataHoraCotacao': '2016-02-12 13:11:55.434'},
#   {'cotacaoCompra': 3.9879,
#    'cotacaoVenda': 3.9885,
#    'dataHoraCotacao': '2016-02-15 13:09:18.754'},
#   {'cotacaoCompra': 4.0207,
#    'cotacaoVenda': 4.0213,
#    'dataHoraCotacao': '2016-02-16 13:04:47.221'},
#   {'cotacaoCompra': 4.0312,
#    'cotacaoVenda': 4.0318,
#    'dataHoraCotacao': '2016-02-17 13:03:45.488'},
#   {'cotacaoCompra': 4.0084,
#    'cotacaoVenda': 4.0091,
#    'dataHoraCotacao': '2016-02-18 13:04:48.92'},
#   {'cotacaoCompra': 4.0486,
#    'cotacaoVenda': 4.0492,
#    'dataHoraCotacao': '2016-02-19 13:03:21.661'},
#   {'cotacaoCompra': 3.9612,
#    'cotacaoVenda': 3.9618,
#    'dataHoraCotacao': '2016-02-22 13:09:39.999'},
#   {'cotacaoCompra': 3.9678,
#    'cotacaoVenda': 3.9684,
#    'dataHoraCotacao': '2016-02-23 13:10:57.68'},
#   {'cotacaoCompra': 3.9894,
#    'cotacaoVenda': 3.99,
#    'dataHoraCotacao': '2016-02-24 13:04:50.209'},
#   {'cotacaoCompra': 3.9394,
#    'cotacaoVenda': 3.94,
#    'dataHoraCotacao': '2016-02-25 13:02:51.663'},
#   {'cotacaoCompra': 3.9571,
#    'cotacaoVenda': 3.9578,
#    'dataHoraCotacao': '2016-02-26 13:05:14.161'},
#   {'cotacaoCompra': 3.979,
#    'cotacaoVenda': 3.9796,
#    'dataHoraCotacao': '2016-02-29 13:03:49.471'},
#   {'cotacaoCompra': 3.9907,
#    'cotacaoVenda': 3.9913,
#    'dataHoraCotacao': '2016-03-01 13:10:04.662'},
#   {'cotacaoCompra': 3.911,
#    'cotacaoVenda': 3.9116,
#    'dataHoraCotacao': '2016-03-02 13:12:16.932'},
#   {'cotacaoCompra': 3.8498,
#    'cotacaoVenda': 3.8504,
#    'dataHoraCotacao': '2016-03-03 13:04:27.128'},
#   {'cotacaoCompra': 3.7182,
#    'cotacaoVenda': 3.7188,
#    'dataHoraCotacao': '2016-03-04 13:06:46.766'},
#   {'cotacaoCompra': 3.7708,
#    'cotacaoVenda': 3.7714,
#    'dataHoraCotacao': '2016-03-07 13:02:47.751'},
#   {'cotacaoCompra': 3.7807,
#    'cotacaoVenda': 3.7813,
#    'dataHoraCotacao': '2016-03-08 13:08:58.704'},
#   {'cotacaoCompra': 3.7031,
#    'cotacaoVenda': 3.7037,
#    'dataHoraCotacao': '2016-03-09 13:04:45.382'},
#   {'cotacaoCompra': 3.6694,
#    'cotacaoVenda': 3.67,
#    'dataHoraCotacao': '2016-03-10 13:10:39.631'},
#   {'cotacaoCompra': 3.6265,
#    'cotacaoVenda': 3.6271,
#    'dataHoraCotacao': '2016-03-11 13:11:02.38'},
#   {'cotacaoCompra': 3.6232,
#    'cotacaoVenda': 3.6239,
#    'dataHoraCotacao': '2016-03-14 13:09:45.239'},
#   {'cotacaoCompra': 3.711,
#    'cotacaoVenda': 3.7116,
#    'dataHoraCotacao': '2016-03-15 13:08:47.766'},
#   {'cotacaoCompra': 3.8073,
#    'cotacaoVenda': 3.8079,
#    'dataHoraCotacao': '2016-03-16 13:08:09.637'},
#   {'cotacaoCompra': 3.6439,
#    'cotacaoVenda': 3.6445,
#    'dataHoraCotacao': '2016-03-17 13:08:35.733'},
#   {'cotacaoCompra': 3.614,
#    'cotacaoVenda': 3.6146,
#    'dataHoraCotacao': '2016-03-18 13:02:51.239'},
#   {'cotacaoCompra': 3.6223,
#    'cotacaoVenda': 3.6229,
#    'dataHoraCotacao': '2016-03-21 13:03:49.98'},
#   {'cotacaoCompra': 3.6067,
#    'cotacaoVenda': 3.6073,
#    'dataHoraCotacao': '2016-03-22 13:10:59.938'},
#   {'cotacaoCompra': 3.6525,
#    'cotacaoVenda': 3.6531,
#    'dataHoraCotacao': '2016-03-23 13:02:59.252'},
#   {'cotacaoCompra': 3.6942,
#    'cotacaoVenda': 3.6948,
#    'dataHoraCotacao': '2016-03-24 13:11:24.799'},
#   {'cotacaoCompra': 3.6401,
#    'cotacaoVenda': 3.6408,
#    'dataHoraCotacao': '2016-03-28 13:10:30.566'},
#   {'cotacaoCompra': 3.6681,
#    'cotacaoVenda': 3.6687,
#    'dataHoraCotacao': '2016-03-29 13:04:59.153'},
#   {'cotacaoCompra': 3.611,
#    'cotacaoVenda': 3.6116,
#    'dataHoraCotacao': '2016-03-30 13:06:05.169'},
#   {'cotacaoCompra': 3.5583,
#    'cotacaoVenda': 3.5589,
#    'dataHoraCotacao': '2016-03-31 13:08:45.137'},
#   {'cotacaoCompra': 3.5793,
#    'cotacaoVenda': 3.5799,
#    'dataHoraCotacao': '2016-04-01 13:11:52.235'},
#   {'cotacaoCompra': 3.5865,
#    'cotacaoVenda': 3.5871,
#    'dataHoraCotacao': '2016-04-04 13:06:46.201'},
#   {'cotacaoCompra': 3.6575,
#    'cotacaoVenda': 3.6581,
#    'dataHoraCotacao': '2016-04-05 13:11:59.295'},
#   {'cotacaoCompra': 3.6743,
#    'cotacaoVenda': 3.6749,
#    'dataHoraCotacao': '2016-04-06 13:16:18.481'},
#   {'cotacaoCompra': 3.6915,
#    'cotacaoVenda': 3.6921,
#    'dataHoraCotacao': '2016-04-07 13:08:41.439'},
#   {'cotacaoCompra': 3.6379,
#    'cotacaoVenda': 3.6385,
#    'dataHoraCotacao': '2016-04-08 13:04:13.177'},
#   {'cotacaoCompra': 3.5278,
#    'cotacaoVenda': 3.5284,
#    'dataHoraCotacao': '2016-04-11 13:08:00.229'},
#   {'cotacaoCompra': 3.54,
#    'cotacaoVenda': 3.5406,
#    'dataHoraCotacao': '2016-04-12 13:09:30.47'},
#   {'cotacaoCompra': 3.5423,
#    'cotacaoVenda': 3.5429,
#    'dataHoraCotacao': '2016-04-13 13:07:11.096'},
#   {'cotacaoCompra': 3.512,
#    'cotacaoVenda': 3.5126,
#    'dataHoraCotacao': '2016-04-14 13:09:46.372'},
#   {'cotacaoCompra': 3.527,
#    'cotacaoVenda': 3.5276,
#    'dataHoraCotacao': '2016-04-15 13:04:06.093'},
#   {'cotacaoCompra': 3.5898,
#    'cotacaoVenda': 3.5904,
#    'dataHoraCotacao': '2016-04-18 13:09:20.47'},
#   {'cotacaoCompra': 3.5532,
#    'cotacaoVenda': 3.5538,
#    'dataHoraCotacao': '2016-04-19 13:12:37.372'},
#   {'cotacaoCompra': 3.5497,
#    'cotacaoVenda': 3.5503,
#    'dataHoraCotacao': '2016-04-20 13:11:54.962'},
#   {'cotacaoCompra': 3.5823,
#    'cotacaoVenda': 3.5829,
#    'dataHoraCotacao': '2016-04-22 13:13:03.706'},
#   {'cotacaoCompra': 3.5466,
#    'cotacaoVenda': 3.5472,
#    'dataHoraCotacao': '2016-04-25 13:03:45.513'},
#   {'cotacaoCompra': 3.5294,
#    'cotacaoVenda': 3.5301,
#    'dataHoraCotacao': '2016-04-26 13:04:51.206'},
#   {'cotacaoCompra': 3.5289,
#    'cotacaoVenda': 3.5295,
#    'dataHoraCotacao': '2016-04-27 13:13:36.409'},
#   {'cotacaoCompra': 3.4986,
#    'cotacaoVenda': 3.4992,
#    'dataHoraCotacao': '2016-04-28 13:07:39.238'},
#   {'cotacaoCompra': 3.4502,
#    'cotacaoVenda': 3.4508,
#    'dataHoraCotacao': '2016-04-29 13:06:42.753'},
#   {'cotacaoCompra': 3.4985,
#    'cotacaoVenda': 3.4991,
#    'dataHoraCotacao': '2016-05-02 13:04:04.383'},
#   {'cotacaoCompra': 3.5544,
#    'cotacaoVenda': 3.555,
#    'dataHoraCotacao': '2016-05-03 13:07:03.616'},
#   {'cotacaoCompra': 3.5391,
#    'cotacaoVenda': 3.5397,
#    'dataHoraCotacao': '2016-05-04 13:07:49.091'},
#   {'cotacaoCompra': 3.529,
#    'cotacaoVenda': 3.5296,
#    'dataHoraCotacao': '2016-05-05 13:04:54.376'},
#   {'cotacaoCompra': 3.5356,
#    'cotacaoVenda': 3.5362,
#    'dataHoraCotacao': '2016-05-06 13:03:28.402'},
#   {'cotacaoCompra': 3.538,
#    'cotacaoVenda': 3.5387,
#    'dataHoraCotacao': '2016-05-09 13:11:14.121'},
#   {'cotacaoCompra': 3.4766,
#    'cotacaoVenda': 3.4772,
#    'dataHoraCotacao': '2016-05-10 13:03:44.346'},
#   {'cotacaoCompra': 3.4639,
#    'cotacaoVenda': 3.4645,
#    'dataHoraCotacao': '2016-05-11 13:06:21.652'},
#   {'cotacaoCompra': 3.4871,
#    'cotacaoVenda': 3.4877,
#    'dataHoraCotacao': '2016-05-12 13:11:02.319'},
#   {'cotacaoCompra': 3.5035,
#    'cotacaoVenda': 3.5041,
#    'dataHoraCotacao': '2016-05-13 13:12:12.504'},
#   {'cotacaoCompra': 3.5029,
#    'cotacaoVenda': 3.5035,
#    'dataHoraCotacao': '2016-05-16 13:10:22.075'},
#   {'cotacaoCompra': 3.5031,
#    'cotacaoVenda': 3.5037,
#    'dataHoraCotacao': '2016-05-17 13:09:33.835'},
#   {'cotacaoCompra': 3.5362,
#    'cotacaoVenda': 3.5368,
#    'dataHoraCotacao': '2016-05-18 13:11:24.699'},
#   {'cotacaoCompra': 3.5997,
#    'cotacaoVenda': 3.6003,
#    'dataHoraCotacao': '2016-05-19 13:04:31.859'},
#   {'cotacaoCompra': 3.5413,
#    'cotacaoVenda': 3.5419,
#    'dataHoraCotacao': '2016-05-20 13:09:54.015'},
#   {'cotacaoCompra': 3.5654,
#    'cotacaoVenda': 3.566,
#    'dataHoraCotacao': '2016-05-23 13:05:14.045'},
#   {'cotacaoCompra': 3.5485,
#    'cotacaoVenda': 3.5491,
#    'dataHoraCotacao': '2016-05-24 13:08:41.68'},
#   {'cotacaoCompra': 3.5798,
#    'cotacaoVenda': 3.5804,
#    'dataHoraCotacao': '2016-05-25 13:06:01.089'},
#   {'cotacaoCompra': 3.6162,
#    'cotacaoVenda': 3.6168,
#    'dataHoraCotacao': '2016-05-27 13:06:17.702'},
#   {'cotacaoCompra': 3.5991,
#    'cotacaoVenda': 3.5997,
#    'dataHoraCotacao': '2016-05-30 13:07:08.055'},
#   {'cotacaoCompra': 3.5945,
#    'cotacaoVenda': 3.5951,
#    'dataHoraCotacao': '2016-05-31 13:07:15.082'},
#   {'cotacaoCompra': 3.612,
#    'cotacaoVenda': 3.6126,
#    'dataHoraCotacao': '2016-06-01 13:03:32.983'},
#   {'cotacaoCompra': 3.5955,
#    'cotacaoVenda': 3.5961,
#    'dataHoraCotacao': '2016-06-02 13:05:50.107'},
#   {'cotacaoCompra': 3.5403,
#    'cotacaoVenda': 3.5409,
#    'dataHoraCotacao': '2016-06-03 13:07:48.276'},
#   {'cotacaoCompra': 3.5092,
#    'cotacaoVenda': 3.5098,
#    'dataHoraCotacao': '2016-06-06 13:12:07.67'},
#   {'cotacaoCompra': 3.4739,
#    'cotacaoVenda': 3.4745,
#    'dataHoraCotacao': '2016-06-07 13:06:28.539'},
#   {'cotacaoCompra': 3.3892,
#    'cotacaoVenda': 3.3898,
#    'dataHoraCotacao': '2016-06-08 13:12:17.117'},
#   {'cotacaoCompra': 3.3811,
#    'cotacaoVenda': 3.3817,
#    'dataHoraCotacao': '2016-06-09 13:12:22.452'},
#   {'cotacaoCompra': 3.4255,
#    'cotacaoVenda': 3.4261,
#    'dataHoraCotacao': '2016-06-10 13:04:54.588'},
#   {'cotacaoCompra': 3.4527,
#    'cotacaoVenda': 3.4533,
#    'dataHoraCotacao': '2016-06-13 13:12:18.113'},
#   {'cotacaoCompra': 3.4833,
#    'cotacaoVenda': 3.4839,
#    'dataHoraCotacao': '2016-06-14 13:11:07.36'},
#   {'cotacaoCompra': 3.4762,
#    'cotacaoVenda': 3.4768,
#    'dataHoraCotacao': '2016-06-15 13:04:07.181'},
#   {'cotacaoCompra': 3.4898,
#    'cotacaoVenda': 3.4904,
#    'dataHoraCotacao': '2016-06-16 13:07:52.127'},
#   {'cotacaoCompra': 3.4366,
#    'cotacaoVenda': 3.4372,
#    'dataHoraCotacao': '2016-06-17 13:16:22.641'},
#   {'cotacaoCompra': 3.3829,
#    'cotacaoVenda': 3.3835,
#    'dataHoraCotacao': '2016-06-20 13:06:11.783'},
#   {'cotacaoCompra': 3.3891,
#    'cotacaoVenda': 3.3897,
#    'dataHoraCotacao': '2016-06-21 13:07:03.812'},
#   {'cotacaoCompra': 3.3877,
#    'cotacaoVenda': 3.3883,
#    'dataHoraCotacao': '2016-06-22 13:07:02.578'},
#   {'cotacaoCompra': 3.3527,
#    'cotacaoVenda': 3.3533,
#    'dataHoraCotacao': '2016-06-23 13:11:59.185'},
#   {'cotacaoCompra': 3.3766,
#    'cotacaoVenda': 3.3772,
#    'dataHoraCotacao': '2016-06-24 13:06:47.87'},
#   {'cotacaoCompra': 3.3928,
#    'cotacaoVenda': 3.3934,
#    'dataHoraCotacao': '2016-06-27 13:07:41.777'},
#   {'cotacaoCompra': 3.3261,
#    'cotacaoVenda': 3.3267,
#    'dataHoraCotacao': '2016-06-28 13:14:20.065'},
#   {'cotacaoCompra': 3.2429,
#    'cotacaoVenda': 3.2435,
#    'dataHoraCotacao': '2016-06-29 13:13:40.493'},
#   {'cotacaoCompra': 3.2092,
#    'cotacaoVenda': 3.2098,
#    'dataHoraCotacao': '2016-06-30 13:09:00.093'},
#   {'cotacaoCompra': 3.2292,
#    'cotacaoVenda': 3.2298,
#    'dataHoraCotacao': '2016-07-01 13:11:49.106'},
#   {'cotacaoCompra': 3.2474,
#    'cotacaoVenda': 3.248,
#    'dataHoraCotacao': '2016-07-04 13:02:59.354'},
#   {'cotacaoCompra': 3.2898,
#    'cotacaoVenda': 3.2904,
#    'dataHoraCotacao': '2016-07-05 13:07:00.556'},
#   {'cotacaoCompra': 3.3236,
#    'cotacaoVenda': 3.3242,
#    'dataHoraCotacao': '2016-07-06 13:09:46.708'},
#   {'cotacaoCompra': 3.3382,
#    'cotacaoVenda': 3.3388,
#    'dataHoraCotacao': '2016-07-07 13:05:33.926'},
#   {'cotacaoCompra': 3.2962,
#    'cotacaoVenda': 3.2968,
#    'dataHoraCotacao': '2016-07-08 13:04:52.766'},
#   {'cotacaoCompra': 3.3025,
#    'cotacaoVenda': 3.3031,
#    'dataHoraCotacao': '2016-07-11 13:04:51.31'},
#   {'cotacaoCompra': 3.2744,
#    'cotacaoVenda': 3.275,
#    'dataHoraCotacao': '2016-07-12 13:04:17.547'},
#   {'cotacaoCompra': 3.289,
#    'cotacaoVenda': 3.2896,
#    'dataHoraCotacao': '2016-07-13 13:04:25.841'},
#   {'cotacaoCompra': 3.2305,
#    'cotacaoVenda': 3.2311,
#    'dataHoraCotacao': '2016-07-14 13:04:56.859'},
#   {'cotacaoCompra': 3.265,
#    'cotacaoVenda': 3.2656,
#    'dataHoraCotacao': '2016-07-15 13:06:54.068'},
#   {'cotacaoCompra': 3.2628,
#    'cotacaoVenda': 3.2634,
#    'dataHoraCotacao': '2016-07-18 13:03:35.615'},
#   {'cotacaoCompra': 3.2795,
#    'cotacaoVenda': 3.2801,
#    'dataHoraCotacao': '2016-07-19 13:09:48.308'},
#   {'cotacaoCompra': 3.2506,
#    'cotacaoVenda': 3.2512,
#    'dataHoraCotacao': '2016-07-20 13:08:49.368'},
#   {'cotacaoCompra': 3.2579,
#    'cotacaoVenda': 3.2585,
#    'dataHoraCotacao': '2016-07-21 13:11:55.399'},
#   {'cotacaoCompra': 3.2848,
#    'cotacaoVenda': 3.2854,
#    'dataHoraCotacao': '2016-07-22 13:08:46.187'},
#   {'cotacaoCompra': 3.2813,
#    'cotacaoVenda': 3.2819,
#    'dataHoraCotacao': '2016-07-25 13:11:09.861'},
#   {'cotacaoCompra': 3.2784,
#    'cotacaoVenda': 3.279,
#    'dataHoraCotacao': '2016-07-26 13:06:02.39'},
#   {'cotacaoCompra': 3.2814,
#    'cotacaoVenda': 3.282,
#    'dataHoraCotacao': '2016-07-27 13:03:49.634'},
#   {'cotacaoCompra': 3.2734,
#    'cotacaoVenda': 3.274,
#    'dataHoraCotacao': '2016-07-28 13:09:51.326'},
#   {'cotacaoCompra': 3.2384,
#    'cotacaoVenda': 3.239,
#    'dataHoraCotacao': '2016-07-29 13:11:02.506'},
#   {'cotacaoCompra': 3.2656,
#    'cotacaoVenda': 3.2662,
#    'dataHoraCotacao': '2016-08-01 13:07:52.331'},
#   {'cotacaoCompra': 3.2484,
#    'cotacaoVenda': 3.249,
#    'dataHoraCotacao': '2016-08-02 13:06:44.706'},
#   {'cotacaoCompra': 3.2727,
#    'cotacaoVenda': 3.2733,
#    'dataHoraCotacao': '2016-08-03 13:04:59.881'},
#   {'cotacaoCompra': 3.2177,
#    'cotacaoVenda': 3.2183,
#    'dataHoraCotacao': '2016-08-04 13:03:54.077'},
#   {'cotacaoCompra': 3.1853,
#    'cotacaoVenda': 3.1859,
#    'dataHoraCotacao': '2016-08-05 13:11:09.805'},
#   {'cotacaoCompra': 3.1765,
#    'cotacaoVenda': 3.1771,
#    'dataHoraCotacao': '2016-08-08 13:11:09.552'},
#   {'cotacaoCompra': 3.1497,
#    'cotacaoVenda': 3.1503,
#    'dataHoraCotacao': '2016-08-09 13:09:55.308'},
#   {'cotacaoCompra': 3.1296,
#    'cotacaoVenda': 3.1302,
#    'dataHoraCotacao': '2016-08-10 13:03:48.37'},
#   {'cotacaoCompra': 3.1358,
#    'cotacaoVenda': 3.1364,
#    'dataHoraCotacao': '2016-08-11 13:10:35.067'},
#   {'cotacaoCompra': 3.1596,
#    'cotacaoVenda': 3.1602,
#    'dataHoraCotacao': '2016-08-12 13:11:59.901'},
#   {'cotacaoCompra': 3.1666,
#    'cotacaoVenda': 3.1672,
#    'dataHoraCotacao': '2016-08-15 13:06:44.773'},
#   {'cotacaoCompra': 3.1743,
#    'cotacaoVenda': 3.1749,
#    'dataHoraCotacao': '2016-08-16 13:04:14.066'},
#   {'cotacaoCompra': 3.2242,
#    'cotacaoVenda': 3.2248,
#    'dataHoraCotacao': '2016-08-17 13:17:38.966'},
#   {'cotacaoCompra': 3.2209,
#    'cotacaoVenda': 3.2215,
#    'dataHoraCotacao': '2016-08-18 13:10:03.273'},
#   {'cotacaoCompra': 3.2261,
#    'cotacaoVenda': 3.2267,
#    'dataHoraCotacao': '2016-08-19 13:04:04.486'},
#   {'cotacaoCompra': 3.2157,
#    'cotacaoVenda': 3.2163,
#    'dataHoraCotacao': '2016-08-22 13:08:52.23'},
#   {'cotacaoCompra': 3.2047,
#    'cotacaoVenda': 3.2054,
#    'dataHoraCotacao': '2016-08-23 13:02:56.681'},
#   {'cotacaoCompra': 3.2366,
#    'cotacaoVenda': 3.2372,
#    'dataHoraCotacao': '2016-08-24 13:08:46.787'},
#   {'cotacaoCompra': 3.2313,
#    'cotacaoVenda': 3.2319,
#    'dataHoraCotacao': '2016-08-25 13:10:46.407'},
#   {'cotacaoCompra': 3.2147,
#    'cotacaoVenda': 3.2153,
#    'dataHoraCotacao': '2016-08-26 13:05:53.75'},
#   {'cotacaoCompra': 3.2607,
#    'cotacaoVenda': 3.2613,
#    'dataHoraCotacao': '2016-08-29 13:18:14.682'},
#   {'cotacaoCompra': 3.2519,
#    'cotacaoVenda': 3.2525,
#    'dataHoraCotacao': '2016-08-30 13:09:35.123'},
#   {'cotacaoCompra': 3.2397,
#    'cotacaoVenda': 3.2403,
#    'dataHoraCotacao': '2016-08-31 13:08:44.335'},
#   {'cotacaoCompra': 3.2466,
#    'cotacaoVenda': 3.2472,
#    'dataHoraCotacao': '2016-09-01 13:10:10.989'},
#   {'cotacaoCompra': 3.2425,
#    'cotacaoVenda': 3.2431,
#    'dataHoraCotacao': '2016-09-02 13:05:51.688'},
#   {'cotacaoCompra': 3.2715,
#    'cotacaoVenda': 3.2721,
#    'dataHoraCotacao': '2016-09-05 13:09:55.659'},
#   {'cotacaoCompra': 3.2446,
#    'cotacaoVenda': 3.2452,
#    'dataHoraCotacao': '2016-09-06 13:02:39.984'},
#   {'cotacaoCompra': 3.1928,
#    'cotacaoVenda': 3.1934,
#    'dataHoraCotacao': '2016-09-08 13:03:53.968'},
#   {'cotacaoCompra': 3.2632,
#    'cotacaoVenda': 3.2638,
#    'dataHoraCotacao': '2016-09-09 13:14:00.885'},
#   {'cotacaoCompra': 3.2848,
#    'cotacaoVenda': 3.2854,
#    'dataHoraCotacao': '2016-09-12 13:08:01.541'},
#   {'cotacaoCompra': 3.2966,
#    'cotacaoVenda': 3.2972,
#    'dataHoraCotacao': '2016-09-13 13:03:56.534'},
#   {'cotacaoCompra': 3.3256,
#    'cotacaoVenda': 3.3262,
#    'dataHoraCotacao': '2016-09-14 13:05:51.819'},
#   {'cotacaoCompra': 3.332,
#    'cotacaoVenda': 3.3326,
#    'dataHoraCotacao': '2016-09-15 13:08:34.825'},
#   {'cotacaoCompra': 3.2998,
#    'cotacaoVenda': 3.3004,
#    'dataHoraCotacao': '2016-09-16 13:04:11.365'},
#   {'cotacaoCompra': 3.263,
#    'cotacaoVenda': 3.2636,
#    'dataHoraCotacao': '2016-09-19 13:07:42.039'},
#   {'cotacaoCompra': 3.2534,
#    'cotacaoVenda': 3.254,
#    'dataHoraCotacao': '2016-09-20 13:12:19.587'},
#   {'cotacaoCompra': 3.2402,
#    'cotacaoVenda': 3.2408,
#    'dataHoraCotacao': '2016-09-21 13:02:47.389'},
#   {'cotacaoCompra': 3.2009,
#    'cotacaoVenda': 3.2015,
#    'dataHoraCotacao': '2016-09-22 13:11:01.456'},
#   {'cotacaoCompra': 3.2236,
#    'cotacaoVenda': 3.2242,
#    'dataHoraCotacao': '2016-09-23 13:07:33.878'},
#   {'cotacaoCompra': 3.2394,
#    'cotacaoVenda': 3.24,
#    'dataHoraCotacao': '2016-09-26 13:03:06.766'},
#   {'cotacaoCompra': 3.2352,
#    'cotacaoVenda': 3.2358,
#    'dataHoraCotacao': '2016-09-27 13:09:07.923'},
#   {'cotacaoCompra': 3.247,
#    'cotacaoVenda': 3.2476,
#    'dataHoraCotacao': '2016-09-28 13:14:19.99'},
#   {'cotacaoCompra': 3.2229,
#    'cotacaoVenda': 3.2235,
#    'dataHoraCotacao': '2016-09-29 13:11:04.635'},
#   {'cotacaoCompra': 3.2456,
#    'cotacaoVenda': 3.2462,
#    'dataHoraCotacao': '2016-09-30 13:05:54.372'},
#   {'cotacaoCompra': 3.2332,
#    'cotacaoVenda': 3.2338,
#    'dataHoraCotacao': '2016-10-03 13:08:48.23'},
#   {'cotacaoCompra': 3.2197,
#    'cotacaoVenda': 3.2203,
#    'dataHoraCotacao': '2016-10-04 13:13:07.366'},
#   {'cotacaoCompra': 3.2353,
#    'cotacaoVenda': 3.2359,
#    'dataHoraCotacao': '2016-10-05 13:05:40.988'},
#   {'cotacaoCompra': 3.2304,
#    'cotacaoVenda': 3.231,
#    'dataHoraCotacao': '2016-10-06 13:13:25.253'},
#   {'cotacaoCompra': 3.2128,
#    'cotacaoVenda': 3.2134,
#    'dataHoraCotacao': '2016-10-07 13:03:53.818'},
#   {'cotacaoCompra': 3.2119,
#    'cotacaoVenda': 3.2125,
#    'dataHoraCotacao': '2016-10-10 13:06:44.704'},
#   {'cotacaoCompra': 3.213,
#    'cotacaoVenda': 3.2136,
#    'dataHoraCotacao': '2016-10-11 13:09:48.113'},
#   {'cotacaoCompra': 3.2081,
#    'cotacaoVenda': 3.2087,
#    'dataHoraCotacao': '2016-10-13 13:04:50.101'},
#   {'cotacaoCompra': 3.1858,
#    'cotacaoVenda': 3.1864,
#    'dataHoraCotacao': '2016-10-14 13:12:14.774'},
#   {'cotacaoCompra': 3.1957,
#    'cotacaoVenda': 3.1963,
#    'dataHoraCotacao': '2016-10-17 13:05:14.708'},
#   {'cotacaoCompra': 3.1868,
#    'cotacaoVenda': 3.1874,
#    'dataHoraCotacao': '2016-10-18 13:09:20.862'},
#   {'cotacaoCompra': 3.1794,
#    'cotacaoVenda': 3.18,
#    'dataHoraCotacao': '2016-10-19 13:10:53.592'},
#   {'cotacaoCompra': 3.1599,
#    'cotacaoVenda': 3.1605,
#    'dataHoraCotacao': '2016-10-20 13:03:10.953'},
#   {'cotacaoCompra': 3.1587,
#    'cotacaoVenda': 3.1593,
#    'dataHoraCotacao': '2016-10-21 13:06:28.783'},
#   {'cotacaoCompra': 3.1305,
#    'cotacaoVenda': 3.1311,
#    'dataHoraCotacao': '2016-10-24 13:02:54.15'},
#   {'cotacaoCompra': 3.1187,
#    'cotacaoVenda': 3.1193,
#    'dataHoraCotacao': '2016-10-25 13:08:42.653'},
#   {'cotacaoCompra': 3.1213,
#    'cotacaoVenda': 3.1219,
#    'dataHoraCotacao': '2016-10-26 13:09:41.53'},
#   {'cotacaoCompra': 3.1423,
#    'cotacaoVenda': 3.1429,
#    'dataHoraCotacao': '2016-10-27 13:04:09.268'},
#   {'cotacaoCompra': 3.1809,
#    'cotacaoVenda': 3.1815,
#    'dataHoraCotacao': '2016-10-28 13:09:46.723'},
#   {'cotacaoCompra': 3.1805,
#    'cotacaoVenda': 3.1811,
#    'dataHoraCotacao': '2016-10-31 13:05:59.103'},
#   {'cotacaoCompra': 3.2047,
#    'cotacaoVenda': 3.2053,
#    'dataHoraCotacao': '2016-11-01 13:12:22.648'},
#   {'cotacaoCompra': 3.2304,
#    'cotacaoVenda': 3.231,
#    'dataHoraCotacao': '2016-11-03 13:13:02.201'},
#   {'cotacaoCompra': 3.2443,
#    'cotacaoVenda': 3.2449,
#    'dataHoraCotacao': '2016-11-04 13:08:46.367'},
#   {'cotacaoCompra': 3.2018,
#    'cotacaoVenda': 3.2024,
#    'dataHoraCotacao': '2016-11-07 13:04:03.991'},
#   {'cotacaoCompra': 3.2018,
#    'cotacaoVenda': 3.2024,
#    'dataHoraCotacao': '2016-11-08 13:11:00.123'},
#   {'cotacaoCompra': 3.2252,
#    'cotacaoVenda': 3.2258,
#    'dataHoraCotacao': '2016-11-09 13:07:07.772'},
#   {'cotacaoCompra': 3.3098,
#    'cotacaoVenda': 3.3104,
#    'dataHoraCotacao': '2016-11-10 13:07:02.302'},
#   {'cotacaoCompra': 3.4371,
#    'cotacaoVenda': 3.4377,
#    'dataHoraCotacao': '2016-11-11 13:04:24.987'},
#   {'cotacaoCompra': 3.444,
#    'cotacaoVenda': 3.4446,
#    'dataHoraCotacao': '2016-11-14 13:04:30.445'},
#   {'cotacaoCompra': 3.4177,
#    'cotacaoVenda': 3.4183,
#    'dataHoraCotacao': '2016-11-16 13:09:06.515'},
#   {'cotacaoCompra': 3.4046,
#    'cotacaoVenda': 3.4052,
#    'dataHoraCotacao': '2016-11-17 13:07:32.351'},
#   {'cotacaoCompra': 3.3911,
#    'cotacaoVenda': 3.3917,
#    'dataHoraCotacao': '2016-11-18 13:10:46.872'},
#   {'cotacaoCompra': 3.3511,
#    'cotacaoVenda': 3.3517,
#    'dataHoraCotacao': '2016-11-21 13:06:39.961'},
#   {'cotacaoCompra': 3.347,
#    'cotacaoVenda': 3.3476,
#    'dataHoraCotacao': '2016-11-22 13:03:49.108'},
#   {'cotacaoCompra': 3.3921,
#    'cotacaoVenda': 3.3927,
#    'dataHoraCotacao': '2016-11-23 13:06:45.266'},
#   {'cotacaoCompra': 3.3981,
#    'cotacaoVenda': 3.3987,
#    'dataHoraCotacao': '2016-11-24 13:08:00.952'},
#   {'cotacaoCompra': 3.4273,
#    'cotacaoVenda': 3.4279,
#    'dataHoraCotacao': '2016-11-25 13:06:32.339'},
#   {'cotacaoCompra': 3.399,
#    'cotacaoVenda': 3.3996,
#    'dataHoraCotacao': '2016-11-28 13:09:49.923'},
#   {'cotacaoCompra': 3.4054,
#    'cotacaoVenda': 3.406,
#    'dataHoraCotacao': '2016-11-29 13:08:56.969'},
#   {'cotacaoCompra': 3.3961,
#    'cotacaoVenda': 3.3967,
#    'dataHoraCotacao': '2016-11-30 13:06:46.879'},
#   {'cotacaoCompra': 3.4356,
#    'cotacaoVenda': 3.4362,
#    'dataHoraCotacao': '2016-12-01 13:11:09.915'},
#   {'cotacaoCompra': 3.4644,
#    'cotacaoVenda': 3.465,
#    'dataHoraCotacao': '2016-12-02 13:05:53.836'},
#   {'cotacaoCompra': 3.4592,
#    'cotacaoVenda': 3.4598,
#    'dataHoraCotacao': '2016-12-05 13:06:12.544'},
#   {'cotacaoCompra': 3.4348,
#    'cotacaoVenda': 3.4354,
#    'dataHoraCotacao': '2016-12-06 13:05:08.947'},
#   {'cotacaoCompra': 3.3889,
#    'cotacaoVenda': 3.3895,
#    'dataHoraCotacao': '2016-12-07 13:08:46.997'},
#   {'cotacaoCompra': 3.4002,
#    'cotacaoVenda': 3.4008,
#    'dataHoraCotacao': '2016-12-08 13:12:01.575'},
#   {'cotacaoCompra': 3.3852,
#    'cotacaoVenda': 3.3858,
#    'dataHoraCotacao': '2016-12-09 13:05:51.876'},
#   {'cotacaoCompra': 3.3691,
#    'cotacaoVenda': 3.3697,
#    'dataHoraCotacao': '2016-12-12 13:07:51.106'},
#   {'cotacaoCompra': 3.3334,
#    'cotacaoVenda': 3.334,
#    'dataHoraCotacao': '2016-12-13 13:08:06.418'},
#   {'cotacaoCompra': 3.3097,
#    'cotacaoVenda': 3.3103,
#    'dataHoraCotacao': '2016-12-14 13:09:51.237'},
#   {'cotacaoCompra': 3.3824,
#    'cotacaoVenda': 3.383,
#    'dataHoraCotacao': '2016-12-15 13:02:46.232'},
#   {'cotacaoCompra': 3.3706,
#    'cotacaoVenda': 3.3712,
#    'dataHoraCotacao': '2016-12-16 13:08:02.388'},
#   {'cotacaoCompra': 3.3772,
#    'cotacaoVenda': 3.3778,
#    'dataHoraCotacao': '2016-12-19 13:12:07.729'},
#   {'cotacaoCompra': 3.358,
#    'cotacaoVenda': 3.3586,
#    'dataHoraCotacao': '2016-12-20 13:05:58.395'},
#   {'cotacaoCompra': 3.3291,
#    'cotacaoVenda': 3.3297,
#    'dataHoraCotacao': '2016-12-21 13:40:41.528'},
#   {'cotacaoCompra': 3.3296,
#    'cotacaoVenda': 3.3302,
#    'dataHoraCotacao': '2016-12-22 13:08:04.834'},
#   {'cotacaoCompra': 3.269,
#    'cotacaoVenda': 3.2696,
#    'dataHoraCotacao': '2016-12-23 13:11:53.756'},
#   {'cotacaoCompra': 3.2695,
#    'cotacaoVenda': 3.2701,
#    'dataHoraCotacao': '2016-12-26 13:12:01.982'},
#   {'cotacaoCompra': 3.277,
#    'cotacaoVenda': 3.2776,
#    'dataHoraCotacao': '2016-12-27 13:06:58.497'},
#   {'cotacaoCompra': 3.2768,
#    'cotacaoVenda': 3.2774,
#    'dataHoraCotacao': '2016-12-28 13:04:46.847'},
#   {'cotacaoCompra': 3.2585,
#    'cotacaoVenda': 3.2591,
#    'dataHoraCotacao': '2016-12-29 13:04:20.815'},
#   {'cotacaoCompra': 3.2585,
#    'cotacaoVenda': 3.2591,
#    'dataHoraCotacao': '2016-12-30 13:02:50.823'},
#   {'cotacaoCompra': 3.2723,
#    'cotacaoVenda': 3.2729,
#    'dataHoraCotacao': '2017-01-02 13:07:18.146'},
#   {'cotacaoCompra': 3.2626,
#    'cotacaoVenda': 3.2632,
#    'dataHoraCotacao': '2017-01-03 13:07:34.023'},
#   {'cotacaoCompra': 3.2327,
#    'cotacaoVenda': 3.2333,
#    'dataHoraCotacao': '2017-01-04 13:11:50.501'},
#   {'cotacaoCompra': 3.2123,
#    'cotacaoVenda': 3.2129,
#    'dataHoraCotacao': '2017-01-05 13:04:07.266'},
#   {'cotacaoCompra': 3.2051,
#    'cotacaoVenda': 3.2057,
#    'dataHoraCotacao': '2017-01-06 13:13:42.955'},
#   {'cotacaoCompra': 3.2091,
#    'cotacaoVenda': 3.2097,
#    'dataHoraCotacao': '2017-01-09 13:08:58.927'},
#   {'cotacaoCompra': 3.1912,
#    'cotacaoVenda': 3.1918,
#    'dataHoraCotacao': '2017-01-10 13:08:06.682'},
#   {'cotacaoCompra': 3.2148,
#    'cotacaoVenda': 3.2154,
#    'dataHoraCotacao': '2017-01-11 13:07:48.319'},
#   {'cotacaoCompra': 3.1655,
#    'cotacaoVenda': 3.1661,
#    'dataHoraCotacao': '2017-01-12 13:03:09.376'},
#   {'cotacaoCompra': 3.2028,
#    'cotacaoVenda': 3.2034,
#    'dataHoraCotacao': '2017-01-13 13:09:16.027'},
#   {'cotacaoCompra': 3.2228,
#    'cotacaoVenda': 3.2234,
#    'dataHoraCotacao': '2017-01-16 13:12:00.606'},
#   {'cotacaoCompra': 3.2094,
#    'cotacaoVenda': 3.21,
#    'dataHoraCotacao': '2017-01-17 13:06:55.733'},
#   {'cotacaoCompra': 3.2205,
#    'cotacaoVenda': 3.2211,
#    'dataHoraCotacao': '2017-01-18 13:05:28.424'},
#   {'cotacaoCompra': 3.2107,
#    'cotacaoVenda': 3.2113,
#    'dataHoraCotacao': '2017-01-19 13:08:52.51'},
#   {'cotacaoCompra': 3.1912,
#    'cotacaoVenda': 3.1918,
#    'dataHoraCotacao': '2017-01-20 13:13:39.174'},
#   {'cotacaoCompra': 3.1603,
#    'cotacaoVenda': 3.1609,
#    'dataHoraCotacao': '2017-01-23 13:12:54.933'},
#   {'cotacaoCompra': 3.1643,
#    'cotacaoVenda': 3.1649,
#    'dataHoraCotacao': '2017-01-24 13:09:02.65'},
#   {'cotacaoCompra': 3.1679,
#    'cotacaoVenda': 3.169,
#    'dataHoraCotacao': '2017-01-25 13:11:24.662'},
#   {'cotacaoCompra': 3.1798,
#    'cotacaoVenda': 3.1804,
#    'dataHoraCotacao': '2017-01-26 13:04:31.844'},
#   {'cotacaoCompra': 3.159,
#    'cotacaoVenda': 3.1596,
#    'dataHoraCotacao': '2017-01-27 13:08:38.93'},
#   {'cotacaoCompra': 3.131,
#    'cotacaoVenda': 3.1316,
#    'dataHoraCotacao': '2017-01-30 13:11:37.661'},
#   {'cotacaoCompra': 3.1264,
#    'cotacaoVenda': 3.127,
#    'dataHoraCotacao': '2017-01-31 13:08:43.585'},
#   {'cotacaoCompra': 3.1473,
#    'cotacaoVenda': 3.1479,
#    'dataHoraCotacao': '2017-02-01 13:05:55.817'},
#   {'cotacaoCompra': 3.119,
#    'cotacaoVenda': 3.1196,
#    'dataHoraCotacao': '2017-02-02 13:12:12.939'},
#   {'cotacaoCompra': 3.1235,
#    'cotacaoVenda': 3.1241,
#    'dataHoraCotacao': '2017-02-03 13:09:11.345'},
#   {'cotacaoCompra': 3.1173,
#    'cotacaoVenda': 3.1179,
#    'dataHoraCotacao': '2017-02-06 13:06:01.029'},
#   {'cotacaoCompra': 3.1298,
#    'cotacaoVenda': 3.1304,
#    'dataHoraCotacao': '2017-02-07 13:08:50.541'},
#   {'cotacaoCompra': 3.1248,
#    'cotacaoVenda': 3.1255,
#    'dataHoraCotacao': '2017-02-08 13:08:38.814'},
#   {'cotacaoCompra': 3.1179,
#    'cotacaoVenda': 3.1185,
#    'dataHoraCotacao': '2017-02-09 13:04:29.047'},
#   {'cotacaoCompra': 3.1149,
#    'cotacaoVenda': 3.1155,
#    'dataHoraCotacao': '2017-02-10 13:05:48.228'},
#   {'cotacaoCompra': 3.1169,
#    'cotacaoVenda': 3.1175,
#    'dataHoraCotacao': '2017-02-13 13:10:48.817'},
#   {'cotacaoCompra': 3.0998,
#    'cotacaoVenda': 3.1004,
#    'dataHoraCotacao': '2017-02-14 13:03:13.887'},
#   {'cotacaoCompra': 3.0773,
#    'cotacaoVenda': 3.0779,
#    'dataHoraCotacao': '2017-02-15 13:06:08.276'},
#   {'cotacaoCompra': 3.0504,
#    'cotacaoVenda': 3.051,
#    'dataHoraCotacao': '2017-02-16 13:08:26.172'},
#   {'cotacaoCompra': 3.0944,
#    'cotacaoVenda': 3.095,
#    'dataHoraCotacao': '2017-02-17 13:08:02.407'},
#   {'cotacaoCompra': 3.0912,
#    'cotacaoVenda': 3.0918,
#    'dataHoraCotacao': '2017-02-20 13:08:26.676'},
#   {'cotacaoCompra': 3.0964,
#    'cotacaoVenda': 3.097,
#    'dataHoraCotacao': '2017-02-21 13:11:26.366'},
#   {'cotacaoCompra': 3.0818,
#    'cotacaoVenda': 3.0824,
#    'dataHoraCotacao': '2017-02-22 13:08:01.394'},
#   {'cotacaoCompra': 3.0632,
#    'cotacaoVenda': 3.0638,
#    'dataHoraCotacao': '2017-02-23 13:04:25.564'},
#   {'cotacaoCompra': 3.0987,
#    'cotacaoVenda': 3.0993,
#    'dataHoraCotacao': '2017-02-24 13:04:50.576'},
#   {'cotacaoCompra': 3.097,
#    'cotacaoVenda': 3.0976,
#    'dataHoraCotacao': '2017-03-01 15:37:01.96'},
#   {'cotacaoCompra': 3.1132,
#    'cotacaoVenda': 3.1138,
#    'dataHoraCotacao': '2017-03-02 13:06:27.32'},
#   {'cotacaoCompra': 3.1358,
#    'cotacaoVenda': 3.1364,
#    'dataHoraCotacao': '2017-03-03 13:07:10.168'},
#   {'cotacaoCompra': 3.1105,
#    'cotacaoVenda': 3.1111,
#    'dataHoraCotacao': '2017-03-06 13:03:53.512'},
#   {'cotacaoCompra': 3.1179,
#    'cotacaoVenda': 3.1185,
#    'dataHoraCotacao': '2017-03-07 13:08:12.549'},
#   {'cotacaoCompra': 3.1471,
#    'cotacaoVenda': 3.1477,
#    'dataHoraCotacao': '2017-03-08 13:03:50.024'},
#   {'cotacaoCompra': 3.1729,
#    'cotacaoVenda': 3.1735,
#    'dataHoraCotacao': '2017-03-09 13:10:47.085'},
#   {'cotacaoCompra': 3.1617,
#    'cotacaoVenda': 3.1623,
#    'dataHoraCotacao': '2017-03-10 13:06:40.688'},
#   {'cotacaoCompra': 3.1535,
#    'cotacaoVenda': 3.1541,
#    'dataHoraCotacao': '2017-03-13 13:03:09.637'},
#   {'cotacaoCompra': 3.1633,
#    'cotacaoVenda': 3.1639,
#    'dataHoraCotacao': '2017-03-14 13:08:15.562'},
#   {'cotacaoCompra': 3.1623,
#    'cotacaoVenda': 3.1629,
#    'dataHoraCotacao': '2017-03-15 13:08:35.316'},
#   {'cotacaoCompra': 3.1074,
#    'cotacaoVenda': 3.108,
#    'dataHoraCotacao': '2017-03-16 13:10:52.126'},
#   {'cotacaoCompra': 3.1069,
#    'cotacaoVenda': 3.1075,
#    'dataHoraCotacao': '2017-03-17 13:05:02.642'},
#   {'cotacaoCompra': 3.0892,
#    'cotacaoVenda': 3.0898,
#    'dataHoraCotacao': '2017-03-20 13:10:47.051'},
#   {'cotacaoCompra': 3.0759,
#    'cotacaoVenda': 3.0765,
#    'dataHoraCotacao': '2017-03-21 13:03:42.922'},
#   {'cotacaoCompra': 3.0933,
#    'cotacaoVenda': 3.0939,
#    'dataHoraCotacao': '2017-03-22 13:02:37.397'},
#   {'cotacaoCompra': 3.1242,
#    'cotacaoVenda': 3.1248,
#    'dataHoraCotacao': '2017-03-23 13:11:51.958'},
#   {'cotacaoCompra': 3.1276,
#    'cotacaoVenda': 3.1282,
#    'dataHoraCotacao': '2017-03-24 13:05:41.423'},
#   {'cotacaoCompra': 3.125,
#    'cotacaoVenda': 3.1256,
#    'dataHoraCotacao': '2017-03-27 13:09:39.543'},
#   {'cotacaoCompra': 3.1297,
#    'cotacaoVenda': 3.1303,
#    'dataHoraCotacao': '2017-03-28 13:05:53.887'},
#   {'cotacaoCompra': 3.1223,
#    'cotacaoVenda': 3.1229,
#    'dataHoraCotacao': '2017-03-29 13:07:50.06'},
#   {'cotacaoCompra': 3.1241,
#    'cotacaoVenda': 3.1247,
#    'dataHoraCotacao': '2017-03-30 13:04:37.167'},
#   {'cotacaoCompra': 3.1678,
#    'cotacaoVenda': 3.1684,
#    'dataHoraCotacao': '2017-03-31 13:04:37.024'},
#   {'cotacaoCompra': 3.1161,
#    'cotacaoVenda': 3.1167,
#    'dataHoraCotacao': '2017-04-03 13:11:51.252'},
#   {'cotacaoCompra': 3.1225,
#    'cotacaoVenda': 3.1231,
#    'dataHoraCotacao': '2017-04-04 13:14:37.607'},
#   {'cotacaoCompra': 3.0917,
#    'cotacaoVenda': 3.0923,
#    'dataHoraCotacao': '2017-04-05 13:09:36.589'},
#   {'cotacaoCompra': 3.1154,
#    'cotacaoVenda': 3.116,
#    'dataHoraCotacao': '2017-04-06 13:03:01.171'},
#   {'cotacaoCompra': 3.1296,
#    'cotacaoVenda': 3.1302,
#    'dataHoraCotacao': '2017-04-07 13:04:41.774'},
#   {'cotacaoCompra': 3.1403,
#    'cotacaoVenda': 3.1409,
#    'dataHoraCotacao': '2017-04-10 13:04:10.183'},
#   {'cotacaoCompra': 3.1418,
#    'cotacaoVenda': 3.1424,
#    'dataHoraCotacao': '2017-04-11 13:12:29.768'},
#   {'cotacaoCompra': 3.1457,
#    'cotacaoVenda': 3.1463,
#    'dataHoraCotacao': '2017-04-12 13:06:48.766'},
#   {'cotacaoCompra': 3.1263,
#    'cotacaoVenda': 3.1269,
#    'dataHoraCotacao': '2017-04-13 13:09:28.107'},
#   {'cotacaoCompra': 3.103,
#    'cotacaoVenda': 3.1036,
#    'dataHoraCotacao': '2017-04-17 13:05:51.148'},
#   {'cotacaoCompra': 3.0952,
#    'cotacaoVenda': 3.0958,
#    'dataHoraCotacao': '2017-04-18 13:11:11.625'},
#   {'cotacaoCompra': 3.1288,
#    'cotacaoVenda': 3.1294,
#    'dataHoraCotacao': '2017-04-19 13:09:50.695'},
#   {'cotacaoCompra': 3.1447,
#    'cotacaoVenda': 3.1453,
#    'dataHoraCotacao': '2017-04-20 13:10:38.938'},
#   {'cotacaoCompra': 3.1245,
#    'cotacaoVenda': 3.1251,
#    'dataHoraCotacao': '2017-04-24 13:06:53.08'},
#   {'cotacaoCompra': 3.1571,
#    'cotacaoVenda': 3.1577,
#    'dataHoraCotacao': '2017-04-25 13:12:37.494'},
#   {'cotacaoCompra': 3.1841,
#    'cotacaoVenda': 3.1847,
#    'dataHoraCotacao': '2017-04-26 13:02:41.795'},
#   {'cotacaoCompra': 3.1757,
#    'cotacaoVenda': 3.1763,
#    'dataHoraCotacao': '2017-04-27 13:04:42.331'},
#   {'cotacaoCompra': 3.1978,
#    'cotacaoVenda': 3.1984,
#    'dataHoraCotacao': '2017-04-28 13:10:52.336'},
#   {'cotacaoCompra': 3.1718,
#    'cotacaoVenda': 3.1724,
#    'dataHoraCotacao': '2017-05-02 13:05:31.845'},
#   {'cotacaoCompra': 3.1483,
#    'cotacaoVenda': 3.1489,
#    'dataHoraCotacao': '2017-05-03 13:11:44.442'},
#   {'cotacaoCompra': 3.1774,
#    'cotacaoVenda': 3.178,
#    'dataHoraCotacao': '2017-05-04 13:06:37.798'},
#   {'cotacaoCompra': 3.1758,
#    'cotacaoVenda': 3.1764,
#    'dataHoraCotacao': '2017-05-05 13:10:18.101'},
#   {'cotacaoCompra': 3.1932,
#    'cotacaoVenda': 3.1938,
#    'dataHoraCotacao': '2017-05-08 13:09:42.404'},
#   {'cotacaoCompra': 3.1851,
#    'cotacaoVenda': 3.1857,
#    'dataHoraCotacao': '2017-05-09 13:07:46.101'},
#   {'cotacaoCompra': 3.16,
#    'cotacaoVenda': 3.1606,
#    'dataHoraCotacao': '2017-05-10 13:02:56.565'},
#   {'cotacaoCompra': 3.1553,
#    'cotacaoVenda': 3.1559,
#    'dataHoraCotacao': '2017-05-11 13:09:03.951'},
#   {'cotacaoCompra': 3.1284,
#    'cotacaoVenda': 3.129,
#    'dataHoraCotacao': '2017-05-12 13:09:38.952'},
#   {'cotacaoCompra': 3.1005,
#    'cotacaoVenda': 3.1011,
#    'dataHoraCotacao': '2017-05-15 13:10:14.948'},
#   {'cotacaoCompra': 3.0918,
#    'cotacaoVenda': 3.0924,
#    'dataHoraCotacao': '2017-05-16 13:06:34.653'},
#   {'cotacaoCompra': 3.107,
#    'cotacaoVenda': 3.1076,
#    'dataHoraCotacao': '2017-05-17 13:12:09.748'},
#   {'cotacaoCompra': 3.3756,
#    'cotacaoVenda': 3.3807,
#    'dataHoraCotacao': '2017-05-18 13:05:58.487'},
#   {'cotacaoCompra': 3.2872,
#    'cotacaoVenda': 3.2878,
#    'dataHoraCotacao': '2017-05-19 13:11:29.308'},
#   {'cotacaoCompra': 3.2857,
#    'cotacaoVenda': 3.2863,
#    'dataHoraCotacao': '2017-05-22 13:07:00.554'},
#   {'cotacaoCompra': 3.2648,
#    'cotacaoVenda': 3.2654,
#    'dataHoraCotacao': '2017-05-23 13:02:54.33'},
#   {'cotacaoCompra': 3.2623,
#    'cotacaoVenda': 3.2629,
#    'dataHoraCotacao': '2017-05-24 13:07:42.187'},
#   {'cotacaoCompra': 3.2818,
#    'cotacaoVenda': 3.2824,
#    'dataHoraCotacao': '2017-05-25 13:02:59.753'},
#   {'cotacaoCompra': 3.2608,
#    'cotacaoVenda': 3.2614,
#    'dataHoraCotacao': '2017-05-26 13:06:53.597'},
#   {'cotacaoCompra': 3.2703,
#    'cotacaoVenda': 3.2709,
#    'dataHoraCotacao': '2017-05-29 13:09:25.777'},
#   {'cotacaoCompra': 3.2653,
#    'cotacaoVenda': 3.2659,
#    'dataHoraCotacao': '2017-05-30 13:07:25.626'},
#   {'cotacaoCompra': 3.2431,
#    'cotacaoVenda': 3.2437,
#    'dataHoraCotacao': '2017-05-31 13:07:50.415'},
#   {'cotacaoCompra': 3.2301,
#    'cotacaoVenda': 3.2307,
#    'dataHoraCotacao': '2017-06-01 13:09:48.76'},
#   {'cotacaoCompra': 3.2395,
#    'cotacaoVenda': 3.2401,
#    'dataHoraCotacao': '2017-06-02 13:04:05.317'},
#   {'cotacaoCompra': 3.2814,
#    'cotacaoVenda': 3.282,
#    'dataHoraCotacao': '2017-06-05 13:05:00.105'},
#   {'cotacaoCompra': 3.2811,
#    'cotacaoVenda': 3.2817,
#    'dataHoraCotacao': '2017-06-06 13:03:50.101'},
#   {'cotacaoCompra': 3.2741,
#    'cotacaoVenda': 3.2747,
#    'dataHoraCotacao': '2017-06-07 13:10:02.741'},
#   {'cotacaoCompra': 3.2832,
#    'cotacaoVenda': 3.2838,
#    'dataHoraCotacao': '2017-06-08 13:09:17.114'},
#   {'cotacaoCompra': 3.2734,
#    'cotacaoVenda': 3.274,
#    'dataHoraCotacao': '2017-06-09 13:06:44.063'},
#   {'cotacaoCompra': 3.298,
#    'cotacaoVenda': 3.2986,
#    'dataHoraCotacao': '2017-06-12 13:10:22.504'},
#   {'cotacaoCompra': 3.3202,
#    'cotacaoVenda': 3.3208,
#    'dataHoraCotacao': '2017-06-13 13:07:17.021'},
#   {'cotacaoCompra': 3.283,
#    'cotacaoVenda': 3.2836,
#    'dataHoraCotacao': '2017-06-14 13:05:49.215'},
#   {'cotacaoCompra': 3.2886,
#    'cotacaoVenda': 3.2892,
#    'dataHoraCotacao': '2017-06-16 13:09:51.845'},
#   {'cotacaoCompra': 3.2969,
#    'cotacaoVenda': 3.2975,
#    'dataHoraCotacao': '2017-06-19 13:09:35.161'},
#   {'cotacaoCompra': 3.3139,
#    'cotacaoVenda': 3.3145,
#    'dataHoraCotacao': '2017-06-20 13:09:57.194'},
#   {'cotacaoCompra': 3.3241,
#    'cotacaoVenda': 3.3247,
#    'dataHoraCotacao': '2017-06-21 13:06:38.103'},
#   {'cotacaoCompra': 3.3356,
#    'cotacaoVenda': 3.3362,
#    'dataHoraCotacao': '2017-06-22 13:11:48.369'},
#   {'cotacaoCompra': 3.3336,
#    'cotacaoVenda': 3.3342,
#    'dataHoraCotacao': '2017-06-23 13:05:41.49'},
#   {'cotacaoCompra': 3.3122,
#    'cotacaoVenda': 3.3128,
#    'dataHoraCotacao': '2017-06-26 13:03:38.941'},
#   {'cotacaoCompra': 3.3166,
#    'cotacaoVenda': 3.3172,
#    'dataHoraCotacao': '2017-06-27 13:10:03.464'},
#   {'cotacaoCompra': 3.3024,
#    'cotacaoVenda': 3.303,
#    'dataHoraCotacao': '2017-06-28 13:09:53.266'},
#   {'cotacaoCompra': 3.2946,
#    'cotacaoVenda': 3.2952,
#    'dataHoraCotacao': '2017-06-29 13:08:49.398'},
#   {'cotacaoCompra': 3.3076,
#    'cotacaoVenda': 3.3082,
#    'dataHoraCotacao': '2017-06-30 13:07:06.19'},
#   {'cotacaoCompra': 3.3009,
#    'cotacaoVenda': 3.3015,
#    'dataHoraCotacao': '2017-07-03 13:08:51.099'},
#   {'cotacaoCompra': 3.3044,
#    'cotacaoVenda': 3.305,
#    'dataHoraCotacao': '2017-07-04 13:09:38.583'},
#   {'cotacaoCompra': 3.3187,
#    'cotacaoVenda': 3.3193,
#    'dataHoraCotacao': '2017-07-05 13:07:52.841'},
#   {'cotacaoCompra': 3.3058,
#    'cotacaoVenda': 3.3064,
#    'dataHoraCotacao': '2017-07-06 13:10:04.143'},
#   {'cotacaoCompra': 3.2889,
#    'cotacaoVenda': 3.2895,
#    'dataHoraCotacao': '2017-07-07 13:10:59.626'},
#   {'cotacaoCompra': 3.2644,
#    'cotacaoVenda': 3.265,
#    'dataHoraCotacao': '2017-07-10 13:04:58.325'},
#   {'cotacaoCompra': 3.2516,
#    'cotacaoVenda': 3.2522,
#    'dataHoraCotacao': '2017-07-11 13:07:42.2'},
#   {'cotacaoCompra': 3.2258,
#    'cotacaoVenda': 3.2264,
#    'dataHoraCotacao': '2017-07-12 13:05:55.372'},
#   {'cotacaoCompra': 3.2102,
#    'cotacaoVenda': 3.2108,
#    'dataHoraCotacao': '2017-07-13 13:03:24.642'},
#   {'cotacaoCompra': 3.1893,
#    'cotacaoVenda': 3.1899,
#    'dataHoraCotacao': '2017-07-14 13:08:48.555'},
#   {'cotacaoCompra': 3.1815,
#    'cotacaoVenda': 3.1821,
#    'dataHoraCotacao': '2017-07-17 13:06:09.489'},
#   {'cotacaoCompra': 3.1662,
#    'cotacaoVenda': 3.1668,
#    'dataHoraCotacao': '2017-07-18 13:04:08.526'},
#   {'cotacaoCompra': 3.1527,
#    'cotacaoVenda': 3.1533,
#    'dataHoraCotacao': '2017-07-19 13:03:40.198'},
#   {'cotacaoCompra': 3.1396,
#    'cotacaoVenda': 3.1402,
#    'dataHoraCotacao': '2017-07-20 13:11:38.587'},
#   {'cotacaoCompra': 3.125,
#    'cotacaoVenda': 3.1256,
#    'dataHoraCotacao': '2017-07-21 13:06:09.241'},
#   {'cotacaoCompra': 3.1453,
#    'cotacaoVenda': 3.1459,
#    'dataHoraCotacao': '2017-07-24 13:03:28.355'},
#   {'cotacaoCompra': 3.155,
#    'cotacaoVenda': 3.1556,
#    'dataHoraCotacao': '2017-07-25 13:09:53.994'},
#   {'cotacaoCompra': 3.1651,
#    'cotacaoVenda': 3.1657,
#    'dataHoraCotacao': '2017-07-26 13:05:57.227'},
#   {'cotacaoCompra': 3.1507,
#    'cotacaoVenda': 3.1513,
#    'dataHoraCotacao': '2017-07-27 13:02:54.362'},
#   {'cotacaoCompra': 3.1451,
#    'cotacaoVenda': 3.1457,
#    'dataHoraCotacao': '2017-07-28 13:09:51.799'},
#   {'cotacaoCompra': 3.1301,
#    'cotacaoVenda': 3.1307,
#    'dataHoraCotacao': '2017-07-31 13:03:36.031'},
#   {'cotacaoCompra': 3.1154,
#    'cotacaoVenda': 3.1161,
#    'dataHoraCotacao': '2017-08-01 13:08:39.907'},
#   {'cotacaoCompra': 3.1262,
#    'cotacaoVenda': 3.1268,
#    'dataHoraCotacao': '2017-08-02 13:07:58.487'},
#   {'cotacaoCompra': 3.1188,
#    'cotacaoVenda': 3.1194,
#    'dataHoraCotacao': '2017-08-03 13:09:48.89'},
#   {'cotacaoCompra': 3.1218,
#    'cotacaoVenda': 3.1224,
#    'dataHoraCotacao': '2017-08-04 13:12:10.418'},
#   {'cotacaoCompra': 3.1261,
#    'cotacaoVenda': 3.1267,
#    'dataHoraCotacao': '2017-08-07 13:11:31.189'},
#   {'cotacaoCompra': 3.1314,
#    'cotacaoVenda': 3.132,
#    'dataHoraCotacao': '2017-08-08 13:06:34.439'},
#   {'cotacaoCompra': 3.1458,
#    'cotacaoVenda': 3.1464,
#    'dataHoraCotacao': '2017-08-09 13:03:05.856'},
#   {'cotacaoCompra': 3.1537,
#    'cotacaoVenda': 3.1543,
#    'dataHoraCotacao': '2017-08-10 13:09:02.609'},
#   {'cotacaoCompra': 3.1689,
#    'cotacaoVenda': 3.1695,
#    'dataHoraCotacao': '2017-08-11 13:11:15.965'},
#   {'cotacaoCompra': 3.1882,
#    'cotacaoVenda': 3.1888,
#    'dataHoraCotacao': '2017-08-14 13:11:13.161'},
#   {'cotacaoCompra': 3.197,
#    'cotacaoVenda': 3.1976,
#    'dataHoraCotacao': '2017-08-15 13:04:55.968'},
#   {'cotacaoCompra': 3.1664,
#    'cotacaoVenda': 3.167,
#    'dataHoraCotacao': '2017-08-16 13:11:54.575'},
#   {'cotacaoCompra': 3.1597,
#    'cotacaoVenda': 3.1603,
#    'dataHoraCotacao': '2017-08-17 13:10:53.766'},
#   {'cotacaoCompra': 3.1648,
#    'cotacaoVenda': 3.1654,
#    'dataHoraCotacao': '2017-08-18 13:03:04.268'},
#   {'cotacaoCompra': 3.1437,
#    'cotacaoVenda': 3.1443,
#    'dataHoraCotacao': '2017-08-21 13:11:54.232'},
#   {'cotacaoCompra': 3.1533,
#    'cotacaoVenda': 3.1539,
#    'dataHoraCotacao': '2017-08-22 13:07:59.02'},
#   {'cotacaoCompra': 3.1563,
#    'cotacaoVenda': 3.1569,
#    'dataHoraCotacao': '2017-08-23 13:05:00.387'},
#   {'cotacaoCompra': 3.1398,
#    'cotacaoVenda': 3.1404,
#    'dataHoraCotacao': '2017-08-24 13:05:56.945'},
#   {'cotacaoCompra': 3.1456,
#    'cotacaoVenda': 3.1462,
#    'dataHoraCotacao': '2017-08-25 13:03:19.052'},
#   {'cotacaoCompra': 3.1557,
#    'cotacaoVenda': 3.1563,
#    'dataHoraCotacao': '2017-08-28 13:05:53.434'},
#   {'cotacaoCompra': 3.1689,
#    'cotacaoVenda': 3.1695,
#    'dataHoraCotacao': '2017-08-29 13:06:00.742'},
#   {'cotacaoCompra': 3.1632,
#    'cotacaoVenda': 3.1638,
#    'dataHoraCotacao': '2017-08-30 13:05:59.376'},
#   {'cotacaoCompra': 3.1465,
#    'cotacaoVenda': 3.1471,
#    'dataHoraCotacao': '2017-08-31 13:11:19.431'},
#   {'cotacaoCompra': 3.1327,
#    'cotacaoVenda': 3.1333,
#    'dataHoraCotacao': '2017-09-01 13:09:49.668'},
#   {'cotacaoCompra': 3.1383,
#    'cotacaoVenda': 3.1389,
#    'dataHoraCotacao': '2017-09-04 13:07:00.053'},
#   {'cotacaoCompra': 3.1197,
#    'cotacaoVenda': 3.1203,
#    'dataHoraCotacao': '2017-09-05 13:08:03.538'},
#   {'cotacaoCompra': 3.1127,
#    'cotacaoVenda': 3.1133,
#    'dataHoraCotacao': '2017-09-06 13:04:56.84'},
#   {'cotacaoCompra': 3.0902,
#    'cotacaoVenda': 3.0908,
#    'dataHoraCotacao': '2017-09-08 13:09:47.865'},
#   {'cotacaoCompra': 3.0846,
#    'cotacaoVenda': 3.0852,
#    'dataHoraCotacao': '2017-09-11 13:11:51.904'},
#   {'cotacaoCompra': 3.1138,
#    'cotacaoVenda': 3.1144,
#    'dataHoraCotacao': '2017-09-12 13:10:52.973'},
#   {'cotacaoCompra': 3.1337,
#    'cotacaoVenda': 3.1343,
#    'dataHoraCotacao': '2017-09-13 13:11:12.8'},
#   {'cotacaoCompra': 3.1348,
#    'cotacaoVenda': 3.1354,
#    'dataHoraCotacao': '2017-09-14 13:07:09.055'},
#   {'cotacaoCompra': 3.1249,
#    'cotacaoVenda': 3.1255,
#    'dataHoraCotacao': '2017-09-15 13:09:01.968'},
#   {'cotacaoCompra': 3.1233,
#    'cotacaoVenda': 3.1239,
#    'dataHoraCotacao': '2017-09-18 13:13:53.088'},
#   {'cotacaoCompra': 3.1317,
#    'cotacaoVenda': 3.1323,
#    'dataHoraCotacao': '2017-09-19 13:02:44.498'},
#   {'cotacaoCompra': 3.1275,
#    'cotacaoVenda': 3.1281,
#    'dataHoraCotacao': '2017-09-20 13:07:58.419'},
#   {'cotacaoCompra': 3.1341,
#    'cotacaoVenda': 3.1347,
#    'dataHoraCotacao': '2017-09-21 13:04:20.434'},
#   {'cotacaoCompra': 3.1279,
#    'cotacaoVenda': 3.1285,
#    'dataHoraCotacao': '2017-09-22 13:04:39.003'},
#   {'cotacaoCompra': 3.1406,
#    'cotacaoVenda': 3.1412,
#    'dataHoraCotacao': '2017-09-25 13:08:41.647'},
#   {'cotacaoCompra': 3.1668,
#    'cotacaoVenda': 3.1674,
#    'dataHoraCotacao': '2017-09-26 13:11:49.126'},
#   {'cotacaoCompra': 3.1926,
#    'cotacaoVenda': 3.1932,
#    'dataHoraCotacao': '2017-09-27 13:03:56.33'},
#   {'cotacaoCompra': 3.1865,
#    'cotacaoVenda': 3.1871,
#    'dataHoraCotacao': '2017-09-28 13:07:41.741'},
#   {'cotacaoCompra': 3.1674,
#    'cotacaoVenda': 3.168,
#    'dataHoraCotacao': '2017-09-29 13:10:53.153'},
#   {'cotacaoCompra': 3.1636,
#    'cotacaoVenda': 3.1642,
#    'dataHoraCotacao': '2017-10-02 13:11:53.361'},
#   {'cotacaoCompra': 3.1496,
#    'cotacaoVenda': 3.1502,
#    'dataHoraCotacao': '2017-10-03 13:06:01.897'},
#   {'cotacaoCompra': 3.1309,
#    'cotacaoVenda': 3.1315,
#    'dataHoraCotacao': '2017-10-04 13:07:04.54'},
#   {'cotacaoCompra': 3.1341,
#    'cotacaoVenda': 3.1347,
#    'dataHoraCotacao': '2017-10-05 13:09:02.854'},
#   {'cotacaoCompra': 3.1642,
#    'cotacaoVenda': 3.1648,
#    'dataHoraCotacao': '2017-10-06 13:12:13.52'},
#   {'cotacaoCompra': 3.1764,
#    'cotacaoVenda': 3.177,
#    'dataHoraCotacao': '2017-10-09 13:03:37.033'},
#   {'cotacaoCompra': 3.1682,
#    'cotacaoVenda': 3.1688,
#    'dataHoraCotacao': '2017-10-10 13:05:50.117'},
#   {'cotacaoCompra': 3.1633,
#    'cotacaoVenda': 3.1639,
#    'dataHoraCotacao': '2017-10-11 13:06:55.368'},
#   {'cotacaoCompra': 3.1567,
#    'cotacaoVenda': 3.1572,
#    'dataHoraCotacao': '2017-10-13 13:09:01.026'},
#   {'cotacaoCompra': 3.1601,
#    'cotacaoVenda': 3.1607,
#    'dataHoraCotacao': '2017-10-16 13:06:50.682'},
#   {'cotacaoCompra': 3.1763,
#    'cotacaoVenda': 3.1769,
#    'dataHoraCotacao': '2017-10-17 13:08:24.663'},
#   {'cotacaoCompra': 3.1667,
#    'cotacaoVenda': 3.1673,
#    'dataHoraCotacao': '2017-10-18 13:05:11.771'},
#   {'cotacaoCompra': 3.1727,
#    'cotacaoVenda': 3.1732,
#    'dataHoraCotacao': '2017-10-19 13:03:16.171'},
#   {'cotacaoCompra': 3.1827,
#    'cotacaoVenda': 3.1833,
#    'dataHoraCotacao': '2017-10-20 13:06:16.866'},
#   {'cotacaoCompra': 3.1997,
#    'cotacaoVenda': 3.2003,
#    'dataHoraCotacao': '2017-10-23 13:08:10.632'},
#   {'cotacaoCompra': 3.2464,
#    'cotacaoVenda': 3.247,
#    'dataHoraCotacao': '2017-10-24 13:07:51.559'},
#   {'cotacaoCompra': 3.2381,
#    'cotacaoVenda': 3.2387,
#    'dataHoraCotacao': '2017-10-25 13:09:31.655'},
#   {'cotacaoCompra': 3.2438,
#    'cotacaoVenda': 3.2444,
# ...
#    'cotacaoVenda': 4.0513,
#    'dataHoraCotacao': '2019-05-23 13:09:33.448'},
#   {'cotacaoCompra': 4.0316,
#    'cotacaoVenda': 4.0322,
#    'dataHoraCotacao': '2019-05-24 13:07:38.702'},
#   {'cotacaoCompra': 4.0204,
#    'cotacaoVenda': 4.021,
#    'dataHoraCotacao': '2019-05-27 13:04:34.755'},
#   {'cotacaoCompra': 4.0269,
#    'cotacaoVenda': 4.0275,
#    'dataHoraCotacao': '2019-05-28 13:03:31.23'},
#   {'cotacaoCompra': 3.9959,
#    'cotacaoVenda': 3.9965,
#    'dataHoraCotacao': '2019-05-29 13:11:02.403'},
#   {'cotacaoCompra': 3.9714,
#    'cotacaoVenda': 3.972,
#    'dataHoraCotacao': '2019-05-30 13:07:34.494'},
#   {'cotacaoCompra': 3.9401,
#    'cotacaoVenda': 3.9407,
#    'dataHoraCotacao': '2019-05-31 13:10:42.115'},
#   {'cotacaoCompra': 3.8997,
#    'cotacaoVenda': 3.9003,
#    'dataHoraCotacao': '2019-06-03 13:08:39.876'},
#   {'cotacaoCompra': 3.8704,
#    'cotacaoVenda': 3.871,
#    'dataHoraCotacao': '2019-06-04 13:24:17.027'},
#   {'cotacaoCompra': 3.8605,
#    'cotacaoVenda': 3.8611,
#    'dataHoraCotacao': '2019-06-05 13:09:37.223'},
#   {'cotacaoCompra': 3.872,
#    'cotacaoVenda': 3.8726,
#    'dataHoraCotacao': '2019-06-06 13:03:30.338'},
#   {'cotacaoCompra': 3.8565,
#    'cotacaoVenda': 3.8571,
#    'dataHoraCotacao': '2019-06-07 13:10:39.673'},
#   {'cotacaoCompra': 3.8784,
#    'cotacaoVenda': 3.879,
#    'dataHoraCotacao': '2019-06-10 13:08:36.147'},
#   {'cotacaoCompra': 3.8658,
#    'cotacaoVenda': 3.8664,
#    'dataHoraCotacao': '2019-06-11 13:04:06.604'},
#   {'cotacaoCompra': 3.8431,
#    'cotacaoVenda': 3.8437,
#    'dataHoraCotacao': '2019-06-12 13:10:41.911'},
#   {'cotacaoCompra': 3.8423,
#    'cotacaoVenda': 3.8429,
#    'dataHoraCotacao': '2019-06-13 13:04:31.756'},
#   {'cotacaoCompra': 3.8807,
#    'cotacaoVenda': 3.8813,
#    'dataHoraCotacao': '2019-06-14 13:06:45.43'},
#   {'cotacaoCompra': 3.8889,
#    'cotacaoVenda': 3.8895,
#    'dataHoraCotacao': '2019-06-17 13:03:37.449'},
#   {'cotacaoCompra': 3.8602,
#    'cotacaoVenda': 3.8608,
#    'dataHoraCotacao': '2019-06-18 13:02:36.281'},
#   {'cotacaoCompra': 3.8717,
#    'cotacaoVenda': 3.8723,
#    'dataHoraCotacao': '2019-06-19 13:09:35.962'},
#   {'cotacaoCompra': 3.8249,
#    'cotacaoVenda': 3.8255,
#    'dataHoraCotacao': '2019-06-21 13:10:36.087'},
#   {'cotacaoCompra': 3.8228,
#    'cotacaoVenda': 3.8234,
#    'dataHoraCotacao': '2019-06-24 13:10:35.774'},
#   {'cotacaoCompra': 3.8297,
#    'cotacaoVenda': 3.8303,
#    'dataHoraCotacao': '2019-06-25 13:05:36.866'},
#   {'cotacaoCompra': 3.8435,
#    'cotacaoVenda': 3.8441,
#    'dataHoraCotacao': '2019-06-26 13:09:31.528'},
#   {'cotacaoCompra': 3.8636,
#    'cotacaoVenda': 3.8642,
#    'dataHoraCotacao': '2019-06-27 13:09:30.652'},
#   {'cotacaoCompra': 3.8316,
#    'cotacaoVenda': 3.8322,
#    'dataHoraCotacao': '2019-06-28 13:06:29.684'},
#   {'cotacaoCompra': 3.8187,
#    'cotacaoVenda': 3.8193,
#    'dataHoraCotacao': '2019-07-01 13:04:34.81'},
#   {'cotacaoCompra': 3.8558,
#    'cotacaoVenda': 3.8564,
#    'dataHoraCotacao': '2019-07-02 13:02:31.855'},
#   {'cotacaoCompra': 3.8469,
#    'cotacaoVenda': 3.8475,
#    'dataHoraCotacao': '2019-07-03 13:07:11.013'},
#   {'cotacaoCompra': 3.7934,
#    'cotacaoVenda': 3.794,
#    'dataHoraCotacao': '2019-07-04 13:06:38.134'},
#   {'cotacaoCompra': 3.8198,
#    'cotacaoVenda': 3.8204,
#    'dataHoraCotacao': '2019-07-05 13:04:34.465'},
#   {'cotacaoCompra': 3.8059,
#    'cotacaoVenda': 3.8065,
#    'dataHoraCotacao': '2019-07-08 13:03:35.309'},
#   {'cotacaoCompra': 3.7846,
#    'cotacaoVenda': 3.7858,
#    'dataHoraCotacao': '2019-07-09 13:03:34.964'},
#   {'cotacaoCompra': 3.7691,
#    'cotacaoVenda': 3.7697,
#    'dataHoraCotacao': '2019-07-10 13:03:47.446'},
#   {'cotacaoCompra': 3.7527,
#    'cotacaoVenda': 3.7533,
#    'dataHoraCotacao': '2019-07-11 13:09:09.885'},
#   {'cotacaoCompra': 3.7446,
#    'cotacaoVenda': 3.7452,
#    'dataHoraCotacao': '2019-07-12 13:02:53.23'},
#   {'cotacaoCompra': 3.7457,
#    'cotacaoVenda': 3.7463,
#    'dataHoraCotacao': '2019-07-15 13:10:36.121'},
#   {'cotacaoCompra': 3.7618,
#    'cotacaoVenda': 3.7624,
#    'dataHoraCotacao': '2019-07-16 13:10:30.809'},
#   {'cotacaoCompra': 3.7612,
#    'cotacaoVenda': 3.7618,
#    'dataHoraCotacao': '2019-07-17 13:09:33.254'},
#   {'cotacaoCompra': 3.7483,
#    'cotacaoVenda': 3.7489,
#    'dataHoraCotacao': '2019-07-18 13:04:44.397'},
#   {'cotacaoCompra': 3.7402,
#    'cotacaoVenda': 3.7408,
#    'dataHoraCotacao': '2019-07-19 13:09:34.798'},
#   {'cotacaoCompra': 3.7394,
#    'cotacaoVenda': 3.74,
#    'dataHoraCotacao': '2019-07-22 13:10:59.268'},
#   {'cotacaoCompra': 3.7615,
#    'cotacaoVenda': 3.7621,
#    'dataHoraCotacao': '2019-07-23 13:04:46.092'},
#   {'cotacaoCompra': 3.759,
#    'cotacaoVenda': 3.7596,
#    'dataHoraCotacao': '2019-07-24 13:07:35.66'},
#   {'cotacaoCompra': 3.7843,
#    'cotacaoVenda': 3.7849,
#    'dataHoraCotacao': '2019-07-25 13:05:19.674'},
#   {'cotacaoCompra': 3.7735,
#    'cotacaoVenda': 3.7741,
#    'dataHoraCotacao': '2019-07-26 13:05:14.071'},
#   {'cotacaoCompra': 3.7903,
#    'cotacaoVenda': 3.7909,
#    'dataHoraCotacao': '2019-07-29 13:12:02.255'},
#   {'cotacaoCompra': 3.7894,
#    'cotacaoVenda': 3.79,
#    'dataHoraCotacao': '2019-07-30 13:07:28.91'},
#   {'cotacaoCompra': 3.7643,
#    'cotacaoVenda': 3.7649,
#    'dataHoraCotacao': '2019-07-31 13:02:35.129'},
#   {'cotacaoCompra': 3.829,
#    'cotacaoVenda': 3.8296,
#    'dataHoraCotacao': '2019-08-01 13:07:45.977'},
#   {'cotacaoCompra': 3.8733,
#    'cotacaoVenda': 3.8739,
#    'dataHoraCotacao': '2019-08-02 13:10:31.723'},
#   {'cotacaoCompra': 3.9398,
#    'cotacaoVenda': 3.9404,
#    'dataHoraCotacao': '2019-08-05 13:07:35.977'},
#   {'cotacaoCompra': 3.9637,
#    'cotacaoVenda': 3.9643,
#    'dataHoraCotacao': '2019-08-06 13:08:30.747'},
#   {'cotacaoCompra': 3.9844,
#    'cotacaoVenda': 3.985,
#    'dataHoraCotacao': '2019-08-07 13:11:33.02'},
#   {'cotacaoCompra': 3.9403,
#    'cotacaoVenda': 3.9409,
#    'dataHoraCotacao': '2019-08-08 13:08:31.203'},
#   {'cotacaoCompra': 3.9356,
#    'cotacaoVenda': 3.9362,
#    'dataHoraCotacao': '2019-08-09 13:11:33.67'},
#   {'cotacaoCompra': 3.996,
#    'cotacaoVenda': 3.9966,
#    'dataHoraCotacao': '2019-08-12 13:09:45.511'},
#   {'cotacaoCompra': 3.973,
#    'cotacaoVenda': 3.9736,
#    'dataHoraCotacao': '2019-08-13 13:10:36.78'},
#   {'cotacaoCompra': 4.0068,
#    'cotacaoVenda': 4.0074,
#    'dataHoraCotacao': '2019-08-14 13:03:36.417'},
#   {'cotacaoCompra': 4.0182,
#    'cotacaoVenda': 4.0188,
#    'dataHoraCotacao': '2019-08-15 13:07:32.659'},
#   {'cotacaoCompra': 3.9927,
#    'cotacaoVenda': 3.9933,
#    'dataHoraCotacao': '2019-08-16 13:07:37.633'},
#   {'cotacaoCompra': 4.0268,
#    'cotacaoVenda': 4.0274,
#    'dataHoraCotacao': '2019-08-19 13:09:34.29'},
#   {'cotacaoCompra': 4.0419,
#    'cotacaoVenda': 4.0425,
#    'dataHoraCotacao': '2019-08-20 13:05:33.452'},
#   {'cotacaoCompra': 4.0248,
#    'cotacaoVenda': 4.0254,
#    'dataHoraCotacao': '2019-08-21 13:06:56.801'},
#   {'cotacaoCompra': 4.0438,
#    'cotacaoVenda': 4.0444,
#    'dataHoraCotacao': '2019-08-22 13:07:58.71'},
#   {'cotacaoCompra': 4.0845,
#    'cotacaoVenda': 4.0851,
#    'dataHoraCotacao': '2019-08-23 13:03:40.234'},
#   {'cotacaoCompra': 4.1361,
#    'cotacaoVenda': 4.1367,
#    'dataHoraCotacao': '2019-08-26 13:11:38.608'},
#   {'cotacaoCompra': 4.1551,
#    'cotacaoVenda': 4.1557,
#    'dataHoraCotacao': '2019-08-27 13:06:31.644'},
#   {'cotacaoCompra': 4.1553,
#    'cotacaoVenda': 4.1559,
#    'dataHoraCotacao': '2019-08-28 13:04:33.577'},
#   {'cotacaoCompra': 4.1674,
#    'cotacaoVenda': 4.168,
#    'dataHoraCotacao': '2019-08-29 13:09:45.964'},
#   {'cotacaoCompra': 4.1379,
#    'cotacaoVenda': 4.1385,
#    'dataHoraCotacao': '2019-08-30 13:06:39.228'},
#   {'cotacaoCompra': 4.1575,
#    'cotacaoVenda': 4.1581,
#    'dataHoraCotacao': '2019-09-02 13:10:40.575'},
#   {'cotacaoCompra': 4.1651,
#    'cotacaoVenda': 4.1657,
#    'dataHoraCotacao': '2019-09-03 13:05:34.847'},
#   {'cotacaoCompra': 4.1243,
#    'cotacaoVenda': 4.1249,
#    'dataHoraCotacao': '2019-09-04 13:07:49.653'},
#   {'cotacaoCompra': 4.0853,
#    'cotacaoVenda': 4.0859,
#    'dataHoraCotacao': '2019-09-05 13:08:45.272'},
#   {'cotacaoCompra': 4.0644,
#    'cotacaoVenda': 4.065,
#    'dataHoraCotacao': '2019-09-06 13:05:41.348'},
#   {'cotacaoCompra': 4.076,
#    'cotacaoVenda': 4.0766,
#    'dataHoraCotacao': '2019-09-09 13:10:40.723'},
#   {'cotacaoCompra': 4.1102,
#    'cotacaoVenda': 4.1108,
#    'dataHoraCotacao': '2019-09-10 13:11:40.259'},
#   {'cotacaoCompra': 4.0625,
#    'cotacaoVenda': 4.0631,
#    'dataHoraCotacao': '2019-09-11 13:02:33.418'},
#   {'cotacaoCompra': 4.0488,
#    'cotacaoVenda': 4.0494,
#    'dataHoraCotacao': '2019-09-12 13:08:35.864'},
#   {'cotacaoCompra': 4.061,
#    'cotacaoVenda': 4.0616,
#    'dataHoraCotacao': '2019-09-13 13:06:36.853'},
#   {'cotacaoCompra': 4.0866,
#    'cotacaoVenda': 4.0872,
#    'dataHoraCotacao': '2019-09-16 13:04:39.901'},
#   {'cotacaoCompra': 4.0992,
#    'cotacaoVenda': 4.0998,
#    'dataHoraCotacao': '2019-09-17 13:10:32.842'},
#   {'cotacaoCompra': 4.0966,
#    'cotacaoVenda': 4.0972,
#    'dataHoraCotacao': '2019-09-18 13:10:47.836'},
#   {'cotacaoCompra': 4.1387,
#    'cotacaoVenda': 4.1393,
#    'dataHoraCotacao': '2019-09-19 13:08:35.568'},
#   {'cotacaoCompra': 4.1681,
#    'cotacaoVenda': 4.1687,
#    'dataHoraCotacao': '2019-09-20 13:08:37.472'},
#   {'cotacaoCompra': 4.1728,
#    'cotacaoVenda': 4.1734,
#    'dataHoraCotacao': '2019-09-23 13:11:42.21'},
#   {'cotacaoCompra': 4.1715,
#    'cotacaoVenda': 4.1721,
#    'dataHoraCotacao': '2019-09-24 13:07:08.372'},
#   {'cotacaoCompra': 4.1821,
#    'cotacaoVenda': 4.1827,
#    'dataHoraCotacao': '2019-09-25 13:10:01.22'},
#   {'cotacaoCompra': 4.1463,
#    'cotacaoVenda': 4.1469,
#    'dataHoraCotacao': '2019-09-26 13:09:34.075'},
#   {'cotacaoCompra': 4.1581,
#    'cotacaoVenda': 4.1587,
#    'dataHoraCotacao': '2019-09-27 13:08:51.782'},
#   {'cotacaoCompra': 4.1638,
#    'cotacaoVenda': 4.1644,
#    'dataHoraCotacao': '2019-09-30 13:02:55.944'},
#   {'cotacaoCompra': 4.1734,
#    'cotacaoVenda': 4.174,
#    'dataHoraCotacao': '2019-10-01 13:08:33.662'},
#   {'cotacaoCompra': 4.154,
#    'cotacaoVenda': 4.1546,
#    'dataHoraCotacao': '2019-10-02 13:02:48.703'},
#   {'cotacaoCompra': 4.1006,
#    'cotacaoVenda': 4.1012,
#    'dataHoraCotacao': '2019-10-03 13:11:41.292'},
#   {'cotacaoCompra': 4.0604,
#    'cotacaoVenda': 4.061,
#    'dataHoraCotacao': '2019-10-04 13:04:35.207'},
#   {'cotacaoCompra': 4.0682,
#    'cotacaoVenda': 4.0688,
#    'dataHoraCotacao': '2019-10-07 13:10:34.43'},
#   {'cotacaoCompra': 4.0862,
#    'cotacaoVenda': 4.0868,
#    'dataHoraCotacao': '2019-10-08 13:02:31.686'},
#   {'cotacaoCompra': 4.0948,
#    'cotacaoVenda': 4.0954,
#    'dataHoraCotacao': '2019-10-09 13:08:35.025'},
#   {'cotacaoCompra': 4.1139,
#    'cotacaoVenda': 4.1145,
#    'dataHoraCotacao': '2019-10-10 13:09:35.138'},
#   {'cotacaoCompra': 4.1054,
#    'cotacaoVenda': 4.106,
#    'dataHoraCotacao': '2019-10-11 13:02:39.429'},
#   {'cotacaoCompra': 4.1257,
#    'cotacaoVenda': 4.1263,
#    'dataHoraCotacao': '2019-10-14 13:03:44.914'},
#   {'cotacaoCompra': 4.1482,
#    'cotacaoVenda': 4.1488,
#    'dataHoraCotacao': '2019-10-15 13:09:38.123'},
#   {'cotacaoCompra': 4.1708,
#    'cotacaoVenda': 4.1714,
#    'dataHoraCotacao': '2019-10-16 13:04:01.79'},
#   {'cotacaoCompra': 4.1452,
#    'cotacaoVenda': 4.1457,
#    'dataHoraCotacao': '2019-10-17 13:08:38.733'},
#   {'cotacaoCompra': 4.137,
#    'cotacaoVenda': 4.1376,
#    'dataHoraCotacao': '2019-10-18 13:09:37.206'},
#   {'cotacaoCompra': 4.1313,
#    'cotacaoVenda': 4.1319,
#    'dataHoraCotacao': '2019-10-21 13:09:38.032'},
#   {'cotacaoCompra': 4.0852,
#    'cotacaoVenda': 4.0858,
#    'dataHoraCotacao': '2019-10-22 13:10:34.471'},
#   {'cotacaoCompra': 4.0715,
#    'cotacaoVenda': 4.0721,
#    'dataHoraCotacao': '2019-10-23 13:04:41.305'},
#   {'cotacaoCompra': 4.0083,
#    'cotacaoVenda': 4.0089,
#    'dataHoraCotacao': '2019-10-24 13:03:39.623'},
#   {'cotacaoCompra': 4.0127,
#    'cotacaoVenda': 4.0133,
#    'dataHoraCotacao': '2019-10-25 13:10:32.932'},
#   {'cotacaoCompra': 3.9786,
#    'cotacaoVenda': 3.9793,
#    'dataHoraCotacao': '2019-10-28 13:07:35.456'},
#   {'cotacaoCompra': 3.994,
#    'cotacaoVenda': 3.9946,
#    'dataHoraCotacao': '2019-10-29 13:03:33.12'},
#   {'cotacaoCompra': 4.018,
#    'cotacaoVenda': 4.0186,
#    'dataHoraCotacao': '2019-10-30 13:03:36.374'},
#   {'cotacaoCompra': 4.0035,
#    'cotacaoVenda': 4.0041,
#    'dataHoraCotacao': '2019-10-31 13:08:45.496'},
#   {'cotacaoCompra': 3.978,
#    'cotacaoVenda': 3.9786,
#    'dataHoraCotacao': '2019-11-01 13:08:58.001'},
#   {'cotacaoCompra': 3.9916,
#    'cotacaoVenda': 3.9922,
#    'dataHoraCotacao': '2019-11-04 13:03:31.543'},
#   {'cotacaoCompra': 4.0037,
#    'cotacaoVenda': 4.0043,
#    'dataHoraCotacao': '2019-11-05 13:10:31.292'},
#   {'cotacaoCompra': 4.0345,
#    'cotacaoVenda': 4.0351,
#    'dataHoraCotacao': '2019-11-06 13:05:35.675'},
#   {'cotacaoCompra': 4.0921,
#    'cotacaoVenda': 4.0927,
#    'dataHoraCotacao': '2019-11-07 13:11:36.723'},
#   {'cotacaoCompra': 4.1359,
#    'cotacaoVenda': 4.1365,
#    'dataHoraCotacao': '2019-11-08 13:11:39.736'},
#   {'cotacaoCompra': 4.1553,
#    'cotacaoVenda': 4.1559,
#    'dataHoraCotacao': '2019-11-11 13:02:46.598'},
#   {'cotacaoCompra': 4.175,
#    'cotacaoVenda': 4.1756,
#    'dataHoraCotacao': '2019-11-12 13:10:33.461'},
#   {'cotacaoCompra': 4.1761,
#    'cotacaoVenda': 4.1767,
#    'dataHoraCotacao': '2019-11-13 13:04:34.593'},
#   {'cotacaoCompra': 4.1825,
#    'cotacaoVenda': 4.1831,
#    'dataHoraCotacao': '2019-11-14 13:08:20.36'},
#   {'cotacaoCompra': 4.1821,
#    'cotacaoVenda': 4.1827,
#    'dataHoraCotacao': '2019-11-18 13:05:34.414'},
#   {'cotacaoCompra': 4.2078,
#    'cotacaoVenda': 4.2084,
#    'dataHoraCotacao': '2019-11-19 13:07:25.508'},
#   {'cotacaoCompra': 4.2027,
#    'cotacaoVenda': 4.2037,
#    'dataHoraCotacao': '2019-11-20 13:12:51.976'},
#   {'cotacaoCompra': 4.2006,
#    'cotacaoVenda': 4.2012,
#    'dataHoraCotacao': '2019-11-21 13:03:40.946'},
#   {'cotacaoCompra': 4.1826,
#    'cotacaoVenda': 4.1832,
#    'dataHoraCotacao': '2019-11-22 13:10:34.906'},
#   {'cotacaoCompra': 4.2083,
#    'cotacaoVenda': 4.2089,
#    'dataHoraCotacao': '2019-11-25 13:07:45.424'},
#   {'cotacaoCompra': 4.2553,
#    'cotacaoVenda': 4.2559,
#    'dataHoraCotacao': '2019-11-26 13:06:35.051'},
#   {'cotacaoCompra': 4.2596,
#    'cotacaoVenda': 4.2602,
#    'dataHoraCotacao': '2019-11-27 13:09:31.449'},
#   {'cotacaoCompra': 4.2474,
#    'cotacaoVenda': 4.248,
#    'dataHoraCotacao': '2019-11-28 13:05:40.116'},
#   {'cotacaoCompra': 4.2234,
#    'cotacaoVenda': 4.224,
#    'dataHoraCotacao': '2019-11-29 13:07:41.629'},
#   {'cotacaoCompra': 4.2255,
#    'cotacaoVenda': 4.2261,
#    'dataHoraCotacao': '2019-12-02 13:11:22.529'},
#   {'cotacaoCompra': 4.2002,
#    'cotacaoVenda': 4.2008,
#    'dataHoraCotacao': '2019-12-03 13:10:42.091'},
#   {'cotacaoCompra': 4.192,
#    'cotacaoVenda': 4.1926,
#    'dataHoraCotacao': '2019-12-04 13:10:28.492'},
#   {'cotacaoCompra': 4.213,
#    'cotacaoVenda': 4.2136,
#    'dataHoraCotacao': '2019-12-05 13:07:59.411'},
#   {'cotacaoCompra': 4.1777,
#    'cotacaoVenda': 4.1783,
#    'dataHoraCotacao': '2019-12-06 13:06:00.52'},
#   {'cotacaoCompra': 4.1497,
#    'cotacaoVenda': 4.1503,
#    'dataHoraCotacao': '2019-12-09 13:07:15.846'},
#   {'cotacaoCompra': 4.1421,
#    'cotacaoVenda': 4.1427,
#    'dataHoraCotacao': '2019-12-10 13:05:14.56'},
#   {'cotacaoCompra': 4.1147,
#    'cotacaoVenda': 4.1153,
#    'dataHoraCotacao': '2019-12-11 13:03:13.547'},
#   {'cotacaoCompra': 4.1086,
#    'cotacaoVenda': 4.1092,
#    'dataHoraCotacao': '2019-12-12 13:10:39.755'},
#   {'cotacaoCompra': 4.0943,
#    'cotacaoVenda': 4.0949,
#    'dataHoraCotacao': '2019-12-13 13:06:05.033'},
#   {'cotacaoCompra': 4.0795,
#    'cotacaoVenda': 4.0801,
#    'dataHoraCotacao': '2019-12-16 13:15:08.681'},
#   {'cotacaoCompra': 4.0681,
#    'cotacaoVenda': 4.0687,
#    'dataHoraCotacao': '2019-12-17 13:12:11.158'},
#   {'cotacaoCompra': 4.0542,
#    'cotacaoVenda': 4.0548,
#    'dataHoraCotacao': '2019-12-18 13:03:49.714'},
#   {'cotacaoCompra': 4.0627,
#    'cotacaoVenda': 4.0633,
#    'dataHoraCotacao': '2019-12-19 13:09:56.245'},
#   {'cotacaoCompra': 4.0771,
#    'cotacaoVenda': 4.0777,
#    'dataHoraCotacao': '2019-12-20 13:04:53.239'},
#   {'cotacaoCompra': 4.0751,
#    'cotacaoVenda': 4.0757,
#    'dataHoraCotacao': '2019-12-23 13:04:48.847'},
#   {'cotacaoCompra': 4.0793,
#    'cotacaoVenda': 4.0813,
#    'dataHoraCotacao': '2019-12-24 11:05:13.242'},
#   {'cotacaoCompra': 4.0595,
#    'cotacaoVenda': 4.0601,
#    'dataHoraCotacao': '2019-12-26 13:10:22.686'},
#   ...]}

# %% [markdown]
# ### 2. Extração dos valores

# %%
# Extraindo os dados a partir da chave 'value'
df_cambio = pd.DataFrame(dados_json['value'])

# %%
# Visualizando as primeiras linhas para conferência
print("Cotações carregadas com sucesso:")
df_cambio.head()
# Out:
# Cotações carregadas com sucesso:
#    cotacaoCompra  cotacaoVenda          dataHoraCotacao
# 0         4.0380        4.0387  2016-01-04 13:12:41.021
# 1         4.0108        4.0114  2016-01-05 13:12:41.306
# 2         4.0297        4.0303  2016-01-06 13:08:04.506
# 3         4.0469        4.0475  2016-01-07 13:07:20.817
# 4         4.0244        4.0250  2016-01-08 13:11:21.614

# %% [markdown]
# ### 3. Padronização da data para cruzamento de dados

# %%
# Convertendo para formato de data e extraindo apenas o dia
df_cambio['data_ajustada'] = pd.to_datetime(df_cambio['dataHoraCotacao']).dt.date

df_cambio['data_ajustada'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 2511 entries, 0 to 2510
# Series name: data_ajustada
# Non-Null Count  Dtype
# --------------  -----
# 2511 non-null   object
# dtypes: object(1)
# memory usage: 19.7+ KB

# %%
# Renomeando a coluna cotacaoVenda para facilitar o cálculo do prejuízo
df_cambio = df_cambio.rename(columns={'cotacaoVenda': 'taxa_venda_bcb'})

# Mantendo apenas as colunas necessárias para a LH Nautical
df_cambio = df_cambio[['data_ajustada', 'taxa_venda_bcb']]

# %%
df_cambio.sample(5)
# Out:
#      data_ajustada  taxa_venda_bcb
# 1759    2023-01-05          5.4026
# 952     2019-10-18          4.1376
# 1682    2022-09-15          5.2211
# 1079    2020-04-23          5.4467
# 80      2016-04-29          3.4508

# %% [markdown]
# ### 4. Codigo de Integração das APIs e Cálculo de prejuízo

# %%
# Carregar e padronizar as datas de vendas (Resolvendo a inconsistência crítica)
df_vendas = pd.read_csv('datasets/vendas_2023_2024.csv')

# Tentamos converter as datas; onde falhar (por formatos mistos), usamos dayfirst=True
df_vendas['sale_date_dt'] = pd.to_datetime(df_vendas['sale_date'], format='mixed', dayfirst=False)
df_vendas['sale_date_dt'] = df_vendas['sale_date_dt'].dt.date

# %% [markdown]
# df_vendas

# %%
# 2. Carregar o arquivo de custos normalizado (da Questão 3)
df_custos = pd.read_csv('datasets/custos_importacao_normalizado.csv')
df_custos['start_date'] = pd.to_datetime(df_custos['start_date']).dt.date
df_custos
# Out:
#       product_id                       product_name     category  start_date  \
# 0              1        Transponder AIS Maré Magnum  eletrônicos  2016-08-10
# 1              1        Transponder AIS Maré Magnum  eletrônicos  2018-06-15
# 2              1        Transponder AIS Maré Magnum  eletrônicos  2018-09-25
# 3              1        Transponder AIS Maré Magnum  eletrônicos  2019-03-19
# 4              1        Transponder AIS Maré Magnum  eletrônicos  2020-01-17
# ...          ...                                ...          ...         ...
# 1255         150  Cabo de Nylon Danforth Magnum Vox    ancoragem  2023-06-01
# 1256         150  Cabo de Nylon Danforth Magnum Vox    ancoragem  2024-01-31
# 1257         150  Cabo de Nylon Danforth Magnum Vox    ancoragem  2024-08-29
# 1258         150  Cabo de Nylon Danforth Magnum Vox    ancoragem  2024-10-04
# 1259         150  Cabo de Nylon Danforth Magnum Vox    ancoragem  2024-10-25
#
#       usd_price
# 0      10583.63
# 1       8778.36
# 2       8023.87
# 3       8772.78
# 4       7918.18
# ...         ...
# 1255     326.88
# 1256     332.26
# 1257     292.03
# 1258     300.96
# 1259     288.90
#
# [1260 rows x 5 columns]

# %% [markdown]
# ### tentativa via sql

# %%
# Criar conexão SQL em memória
conn = sqlite3.connect(':memory:')

# Salvar tudo como tabelas SQL
df_vendas.to_sql('vendas', conn, index=False, if_exists='replace')
df_custos.to_sql('custos', conn, index=False, if_exists='replace')
df_cambio.to_sql('cambio', conn, index=False, if_exists='replace')

print("Tabelas SQL (vendas, custos e cambio) prontas para consulta.")
# Out:
# Tabelas SQL (vendas, custos e cambio) prontas para consulta.

# %%
query_financeiro = """
WITH Vendas_Com_Cambio AS (
    -- Une vendas com a cotação do BCB do dia exato
    SELECT 
        v.id_product,
        v.qtd,
        v.total AS receita_brl,
        v.sale_date,
        c.taxa_venda_bcb
    FROM vendas v
    JOIN cambio c ON v.sale_date = c.data_ajustada
),
Custo_Vigente AS (
    -- Calcula o custo BRL usando o custo USD unitário vigente na data
    SELECT 
        vcc.*,
        (SELECT usd_price 
         FROM custos 
         WHERE product_id = vcc.id_product 
           AND start_date <= vcc.sale_date
         ORDER BY start_date DESC LIMIT 1) AS usd_price_unitario
    FROM Vendas_Com_Cambio vcc
),
Calculo_Prejuizo AS (
    -- custo_total_brl = (usd_price * taxa_venda * qtd)
    SELECT 
        id_product,
        receita_brl,
        (usd_price_unitario * taxa_venda_bcb * qtd) AS custo_total_brl
    FROM Custo_Vigente
)
SELECT 
    id_product,
    SUM(receita_brl) AS receita_total,
    SUM(CASE WHEN receita_brl < custo_total_brl THEN (custo_total_brl - receita_brl) ELSE 0 END) AS prejuizo_total,
    (SUM(CASE WHEN receita_brl < custo_total_brl THEN (custo_total_brl - receita_brl) ELSE 0 END) / SUM(receita_brl)) * 100 AS percentual_perda
FROM Calculo_Prejuizo
GROUP BY id_product
ORDER BY prejuizo_total DESC;
"""

# %%
# Executando a consulta e exibindo o resultado
df_resultado_sql = pd.read_sql(query_financeiro, conn)
conn.close()
df_resultado_sql
# Out:
#      id_product  receita_total  prejuizo_total  percentual_perda
# 0            72    24691915.25    1.510262e+07         61.164223
# 1            83    14700364.55    6.794119e+06         46.217352
# 2            74    30308479.20    3.474017e+06         11.462194
# 3            71    26594559.95    1.727306e+06          6.494958
# 4            91    20253132.90    1.466769e+06          7.242181
# ..          ...            ...             ...               ...
# 145         105       68068.25    3.108859e+03          4.567267
# 146         126      421904.90    2.463592e+03          0.583921
# 147          13     1431274.80    2.178034e+03          0.152174
# 148         139      307559.90    1.785583e+03          0.580564
# 149         114       84924.90    4.815284e+02          0.567005
#
# [150 rows x 4 columns]

# %%
df_resultado_sql.iloc[df_resultado_sql['percentual_perda'].idxmax()]
# Out:
# id_product          7.200000e+01
# receita_total       2.469192e+07
# prejuizo_total      1.510262e+07
# percentual_perda    6.116422e+01
# Name: 0, dtype: float64
